# %% [markdown]
# # TP Coding autoencoders and variational autoencoders in Pytorch
#
#
# Author : Alasdair Newson
#
# alasdair.newson@telecom-paris.fr
#
# ## Objective:
#
# The goal of this TP is to explore autoencoders and variational autoencoders applied to a simple dataset. In this first part, we will look at an autoencoder applied to MNIST. We recall that an autoencoder is a neural network with the following general architecture:
#
#
# ![AUTOENCODER](https://perso.telecom-paristech.fr/anewson/doc/images/autoencoder_illustration_2.png)
#
# The tensor $z$ in the middle of the network is called a __latent code__, and it belongs to the latent space. It is this latent space which is interesting in autoencoders (for image synthesis, editing, etc).
#
# ### Your task:
# You need to add the missing parts in the code (parts between # --- START CODE HERE and # --- END CODE HERE or # FILL IN CODE)
#
#
# First of all, let's load some packages

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image

import pdb
import numpy as np
import matplotlib.pyplot as plt

def pytorch_to_numpy(x):
  return x.detach().numpy()

# %% [markdown]
# First, we load the mnist dataset.

# %%
batch_size = 128

# MNIST Dataset
mnist_trainset = datasets.MNIST(root='./mnist_data/', train=True, transform=transforms.ToTensor(), download=True)
mnist_testset = datasets.MNIST(root='./mnist_data/', train=False, transform=transforms.ToTensor(), download=False)

#create data loader with smaller dataset size
max_mnist_size = 1000
mnist_trainset_reduced = torch.utils.data.random_split(mnist_trainset, [max_mnist_size, len(mnist_trainset)-max_mnist_size])[0]
mnist_train_loader = torch.utils.data.DataLoader(mnist_trainset_reduced, batch_size=batch_size, shuffle=True,drop_last=True)

# download test dataset
max_mnist_size = 512
mnist_testset_reduced = torch.utils.data.random_split(mnist_testset, [max_mnist_size, len(mnist_testset)-max_mnist_size])[0]
mnist_test_loader = torch.utils.data.DataLoader(mnist_testset_reduced, batch_size=batch_size, shuffle=True,drop_last=True)

# %%
mnist_trainset_reduced.dataset.train_data.shape
# Out:
# /Users/maximemoutet/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torchvision/datasets/mnist.py:76: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# torch.Size([60000, 28, 28])

# %% [markdown]
# # 1 Vanilla Autoencoder
#
# Now, we define the general parameters of the autoencoder

# %%
# autoencoder parameters
n_rows = mnist_trainset_reduced.dataset.train_data.shape[1]
n_cols = mnist_trainset_reduced.dataset.train_data.shape[2]
n_channels = 1
n_pixels = n_rows*n_cols

img_shape = (n_rows, n_cols, n_channels)
n_epochs = 150

# %% [markdown]
# Now, define the autoencoder architecture. In the first part, we will use the following MLP architecture :
#
# Encoder :
# - Flatten input
# - Dense layer, output size h_dim_1 + ReLU
# - Dense layer, output size h_dim_2 + ReLU
# - Dense layer, output size z_dim (no non-linearity)
#
# Decoder :
# - Dense layer, output size h_dim_2 + ReLU
# - Dense layer, output size h_dim_1 + ReLU
# - Dense layer, output size x_dim + Sigmoid Activation
# - Reshape, to size $28\times 28\times 1$
#
# For the Reshape operation, use the ```A.view(dim_1,dim_2,...)``` function, where ```A``` is your tensor.

# %%
class AE(torch.nn.Module ):
  def __init__(self, x_dim, h_dim1, h_dim2, z_dim,n_rows,n_cols,n_channels):
    super(AE, self).__init__()

    self.n_rows = n_rows
    self.n_cols = n_cols
    self.n_channels = n_channels
    self.n_pixels = (self.n_rows)*(self.n_cols)
    self.z_dim = z_dim

    # encoder part
    self.fc1 = nn.Linear(x_dim, h_dim1)
    self.fc2 = nn.Linear(h_dim1, h_dim2)
    self.fc3 = nn.Linear(h_dim2, z_dim)
    # decoder part
    self.fc4 = nn.Linear(z_dim, h_dim2)
    self.fc5 = nn.Linear(h_dim2, h_dim1)
    self.fc6 = nn.Linear(h_dim1, x_dim)

  def encoder(self, x):
    x = x.view(-1, self.n_pixels * self.n_channels) # Flatten the input to (Batch_size, x_dim)
    h = F.relu(self.fc1(x))
    h = F.relu(self.fc2(h))
    return self.fc3(h)

  def decoder(self, z):
    h = F.relu(self.fc4(z))
    h = F.relu(self.fc5(h))
    return F.sigmoid(self.fc6(h)).view(-1, self.n_channels, self.n_rows, self.n_cols)
  
  def forward(self, x):
    z = self.encoder(x)
    y = self.decoder(z)
    return y

  def loss_function(self, x, y):
    mse_loss = (x - y) ** 2 # MSE on each data
    return torch.mean(mse_loss) # MSE on whole batch

# %%
# create model
ae_dim_1 = 512
ae_dim_2 = 256
z_dim = 10
ae_model = AE(x_dim=n_pixels, h_dim1= ae_dim_1, h_dim2=ae_dim_2, z_dim=z_dim,n_rows=n_rows,n_cols=n_cols,n_channels=n_channels)
ae_optimizer = optim.Adam(ae_model.parameters())

# %% [markdown]
# Now, define a generic function to train the model for one epoch

# %%
def train_ae(ae_model, data_train_loader, epoch):
	train_loss = 0
	for batch_idx, (data, _) in enumerate(data_train_loader):
		ae_optimizer.zero_grad()

		y = ae_model(data)
		loss_ae = ae_model.loss_function(y, data)

		loss_ae.backward()
		train_loss += loss_ae.item()
		ae_optimizer.step()

		if batch_idx % 100:
			print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
				epoch, batch_idx * len(data), len(data_train_loader.dataset),
				100. * batch_idx / len(data_train_loader), loss_ae.item() / len(data)))
	print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(data_train_loader.dataset)))

# %% [markdown]
# We define a function to carry out testing on the autoencoder model

# %%
for epoch in range(0, n_epochs):
  train_ae(ae_model, mnist_train_loader, epoch)
# Out:
# Train Epoch: 0 [128/1000 (14%)]	Loss: 0.001767
# Train Epoch: 0 [256/1000 (29%)]	Loss: 0.001719
# Train Epoch: 0 [384/1000 (43%)]	Loss: 0.001617
# Train Epoch: 0 [512/1000 (57%)]	Loss: 0.001455
# Train Epoch: 0 [640/1000 (71%)]	Loss: 0.001200
# Train Epoch: 0 [768/1000 (86%)]	Loss: 0.000902
# ====> Epoch: 0 Average loss: 0.0013
# Train Epoch: 1 [128/1000 (14%)]	Loss: 0.000653
# Train Epoch: 1 [256/1000 (29%)]	Loss: 0.000648
# Train Epoch: 1 [384/1000 (43%)]	Loss: 0.000654
# Train Epoch: 1 [512/1000 (57%)]	Loss: 0.000686
# Train Epoch: 1 [640/1000 (71%)]	Loss: 0.000608
# Train Epoch: 1 [768/1000 (86%)]	Loss: 0.000610
# ====> Epoch: 1 Average loss: 0.0006
# Train Epoch: 2 [128/1000 (14%)]	Loss: 0.000582
# Train Epoch: 2 [256/1000 (29%)]	Loss: 0.000610
# Train Epoch: 2 [384/1000 (43%)]	Loss: 0.000647
# Train Epoch: 2 [512/1000 (57%)]	Loss: 0.000628
# Train Epoch: 2 [640/1000 (71%)]	Loss: 0.000601
# Train Epoch: 2 [768/1000 (86%)]	Loss: 0.000596
# ====> Epoch: 2 Average loss: 0.0006
# Train Epoch: 3 [128/1000 (14%)]	Loss: 0.000580
# Train Epoch: 3 [256/1000 (29%)]	Loss: 0.000583
# Train Epoch: 3 [384/1000 (43%)]	Loss: 0.000565
# Train Epoch: 3 [512/1000 (57%)]	Loss: 0.000566
# Train Epoch: 3 [640/1000 (71%)]	Loss: 0.000594
# Train Epoch: 3 [768/1000 (86%)]	Loss: 0.000569
# ====> Epoch: 3 Average loss: 0.0005
# Train Epoch: 4 [128/1000 (14%)]	Loss: 0.000577
# Train Epoch: 4 [256/1000 (29%)]	Loss: 0.000573
# Train Epoch: 4 [384/1000 (43%)]	Loss: 0.000579
# Train Epoch: 4 [512/1000 (57%)]	Loss: 0.000558
# Train Epoch: 4 [640/1000 (71%)]	Loss: 0.000584
# Train Epoch: 4 [768/1000 (86%)]	Loss: 0.000602
# ====> Epoch: 4 Average loss: 0.0005
# Train Epoch: 5 [128/1000 (14%)]	Loss: 0.000619
# Train Epoch: 5 [256/1000 (29%)]	Loss: 0.000568
# Train Epoch: 5 [384/1000 (43%)]	Loss: 0.000537
# Train Epoch: 5 [512/1000 (57%)]	Loss: 0.000578
# Train Epoch: 5 [640/1000 (71%)]	Loss: 0.000563
# Train Epoch: 5 [768/1000 (86%)]	Loss: 0.000568
# ====> Epoch: 5 Average loss: 0.0005
# Train Epoch: 6 [128/1000 (14%)]	Loss: 0.000576
# Train Epoch: 6 [256/1000 (29%)]	Loss: 0.000565
# Train Epoch: 6 [384/1000 (43%)]	Loss: 0.000549
# Train Epoch: 6 [512/1000 (57%)]	Loss: 0.000534
# Train Epoch: 6 [640/1000 (71%)]	Loss: 0.000556
# Train Epoch: 6 [768/1000 (86%)]	Loss: 0.000567
# ====> Epoch: 6 Average loss: 0.0005
# Train Epoch: 7 [128/1000 (14%)]	Loss: 0.000551
# Train Epoch: 7 [256/1000 (29%)]	Loss: 0.000558
# Train Epoch: 7 [384/1000 (43%)]	Loss: 0.000544
# Train Epoch: 7 [512/1000 (57%)]	Loss: 0.000552
# Train Epoch: 7 [640/1000 (71%)]	Loss: 0.000546
# Train Epoch: 7 [768/1000 (86%)]	Loss: 0.000550
# ====> Epoch: 7 Average loss: 0.0005
# Train Epoch: 8 [128/1000 (14%)]	Loss: 0.000559
# Train Epoch: 8 [256/1000 (29%)]	Loss: 0.000531
# Train Epoch: 8 [384/1000 (43%)]	Loss: 0.000530
# Train Epoch: 8 [512/1000 (57%)]	Loss: 0.000534
# Train Epoch: 8 [640/1000 (71%)]	Loss: 0.000523
# Train Epoch: 8 [768/1000 (86%)]	Loss: 0.000506
# ====> Epoch: 8 Average loss: 0.0005
# Train Epoch: 9 [128/1000 (14%)]	Loss: 0.000512
# Train Epoch: 9 [256/1000 (29%)]	Loss: 0.000512
# Train Epoch: 9 [384/1000 (43%)]	Loss: 0.000509
# Train Epoch: 9 [512/1000 (57%)]	Loss: 0.000522
# Train Epoch: 9 [640/1000 (71%)]	Loss: 0.000519
# Train Epoch: 9 [768/1000 (86%)]	Loss: 0.000507
# ====> Epoch: 9 Average loss: 0.0005
# Train Epoch: 10 [128/1000 (14%)]	Loss: 0.000515
# Train Epoch: 10 [256/1000 (29%)]	Loss: 0.000477
# Train Epoch: 10 [384/1000 (43%)]	Loss: 0.000479
# Train Epoch: 10 [512/1000 (57%)]	Loss: 0.000513
# Train Epoch: 10 [640/1000 (71%)]	Loss: 0.000469
# Train Epoch: 10 [768/1000 (86%)]	Loss: 0.000493
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 11 [128/1000 (14%)]	Loss: 0.000478
# Train Epoch: 11 [256/1000 (29%)]	Loss: 0.000445
# Train Epoch: 11 [384/1000 (43%)]	Loss: 0.000469
# Train Epoch: 11 [512/1000 (57%)]	Loss: 0.000453
# Train Epoch: 11 [640/1000 (71%)]	Loss: 0.000472
# Train Epoch: 11 [768/1000 (86%)]	Loss: 0.000459
# ====> Epoch: 11 Average loss: 0.0004
# Train Epoch: 12 [128/1000 (14%)]	Loss: 0.000443
# Train Epoch: 12 [256/1000 (29%)]	Loss: 0.000454
# Train Epoch: 12 [384/1000 (43%)]	Loss: 0.000465
# Train Epoch: 12 [512/1000 (57%)]	Loss: 0.000441
# Train Epoch: 12 [640/1000 (71%)]	Loss: 0.000463
# Train Epoch: 12 [768/1000 (86%)]	Loss: 0.000455
# ====> Epoch: 12 Average loss: 0.0004
# Train Epoch: 13 [128/1000 (14%)]	Loss: 0.000440
# Train Epoch: 13 [256/1000 (29%)]	Loss: 0.000419
# Train Epoch: 13 [384/1000 (43%)]	Loss: 0.000416
# Train Epoch: 13 [512/1000 (57%)]	Loss: 0.000402
# Train Epoch: 13 [640/1000 (71%)]	Loss: 0.000453
# Train Epoch: 13 [768/1000 (86%)]	Loss: 0.000437
# ====> Epoch: 13 Average loss: 0.0004
# Train Epoch: 14 [128/1000 (14%)]	Loss: 0.000431
# Train Epoch: 14 [256/1000 (29%)]	Loss: 0.000418
# Train Epoch: 14 [384/1000 (43%)]	Loss: 0.000413
# Train Epoch: 14 [512/1000 (57%)]	Loss: 0.000417
# Train Epoch: 14 [640/1000 (71%)]	Loss: 0.000445
# Train Epoch: 14 [768/1000 (86%)]	Loss: 0.000389
# ====> Epoch: 14 Average loss: 0.0004
# Train Epoch: 15 [128/1000 (14%)]	Loss: 0.000376
# Train Epoch: 15 [256/1000 (29%)]	Loss: 0.000408
# Train Epoch: 15 [384/1000 (43%)]	Loss: 0.000405
# Train Epoch: 15 [512/1000 (57%)]	Loss: 0.000387
# Train Epoch: 15 [640/1000 (71%)]	Loss: 0.000397
# Train Epoch: 15 [768/1000 (86%)]	Loss: 0.000396
# ====> Epoch: 15 Average loss: 0.0004
# Train Epoch: 16 [128/1000 (14%)]	Loss: 0.000372
# Train Epoch: 16 [256/1000 (29%)]	Loss: 0.000383
# Train Epoch: 16 [384/1000 (43%)]	Loss: 0.000378
# Train Epoch: 16 [512/1000 (57%)]	Loss: 0.000374
# Train Epoch: 16 [640/1000 (71%)]	Loss: 0.000376
# Train Epoch: 16 [768/1000 (86%)]	Loss: 0.000365
# ====> Epoch: 16 Average loss: 0.0003
# Train Epoch: 17 [128/1000 (14%)]	Loss: 0.000380
# Train Epoch: 17 [256/1000 (29%)]	Loss: 0.000339
# Train Epoch: 17 [384/1000 (43%)]	Loss: 0.000361
# Train Epoch: 17 [512/1000 (57%)]	Loss: 0.000346
# Train Epoch: 17 [640/1000 (71%)]	Loss: 0.000349
# Train Epoch: 17 [768/1000 (86%)]	Loss: 0.000347
# ====> Epoch: 17 Average loss: 0.0003
# Train Epoch: 18 [128/1000 (14%)]	Loss: 0.000342
# Train Epoch: 18 [256/1000 (29%)]	Loss: 0.000335
# Train Epoch: 18 [384/1000 (43%)]	Loss: 0.000335
# Train Epoch: 18 [512/1000 (57%)]	Loss: 0.000340
# Train Epoch: 18 [640/1000 (71%)]	Loss: 0.000338
# Train Epoch: 18 [768/1000 (86%)]	Loss: 0.000333
# ====> Epoch: 18 Average loss: 0.0003
# Train Epoch: 19 [128/1000 (14%)]	Loss: 0.000319
# Train Epoch: 19 [256/1000 (29%)]	Loss: 0.000314
# Train Epoch: 19 [384/1000 (43%)]	Loss: 0.000324
# Train Epoch: 19 [512/1000 (57%)]	Loss: 0.000329
# Train Epoch: 19 [640/1000 (71%)]	Loss: 0.000326
# Train Epoch: 19 [768/1000 (86%)]	Loss: 0.000314
# ====> Epoch: 19 Average loss: 0.0003
# Train Epoch: 20 [128/1000 (14%)]	Loss: 0.000331
# Train Epoch: 20 [256/1000 (29%)]	Loss: 0.000312
# Train Epoch: 20 [384/1000 (43%)]	Loss: 0.000301
# Train Epoch: 20 [512/1000 (57%)]	Loss: 0.000289
# Train Epoch: 20 [640/1000 (71%)]	Loss: 0.000302
# Train Epoch: 20 [768/1000 (86%)]	Loss: 0.000299
# ====> Epoch: 20 Average loss: 0.0003
# Train Epoch: 21 [128/1000 (14%)]	Loss: 0.000296
# Train Epoch: 21 [256/1000 (29%)]	Loss: 0.000294
# Train Epoch: 21 [384/1000 (43%)]	Loss: 0.000299
# Train Epoch: 21 [512/1000 (57%)]	Loss: 0.000275
# Train Epoch: 21 [640/1000 (71%)]	Loss: 0.000289
# Train Epoch: 21 [768/1000 (86%)]	Loss: 0.000299
# ====> Epoch: 21 Average loss: 0.0003
# Train Epoch: 22 [128/1000 (14%)]	Loss: 0.000294
# Train Epoch: 22 [256/1000 (29%)]	Loss: 0.000290
# Train Epoch: 22 [384/1000 (43%)]	Loss: 0.000274
# Train Epoch: 22 [512/1000 (57%)]	Loss: 0.000276
# Train Epoch: 22 [640/1000 (71%)]	Loss: 0.000278
# Train Epoch: 22 [768/1000 (86%)]	Loss: 0.000276
# ====> Epoch: 22 Average loss: 0.0003
# Train Epoch: 23 [128/1000 (14%)]	Loss: 0.000267
# Train Epoch: 23 [256/1000 (29%)]	Loss: 0.000283
# Train Epoch: 23 [384/1000 (43%)]	Loss: 0.000260
# Train Epoch: 23 [512/1000 (57%)]	Loss: 0.000271
# Train Epoch: 23 [640/1000 (71%)]	Loss: 0.000274
# Train Epoch: 23 [768/1000 (86%)]	Loss: 0.000271
# ====> Epoch: 23 Average loss: 0.0002
# Train Epoch: 24 [128/1000 (14%)]	Loss: 0.000264
# Train Epoch: 24 [256/1000 (29%)]	Loss: 0.000264
# Train Epoch: 24 [384/1000 (43%)]	Loss: 0.000261
# Train Epoch: 24 [512/1000 (57%)]	Loss: 0.000257
# Train Epoch: 24 [640/1000 (71%)]	Loss: 0.000257
# Train Epoch: 24 [768/1000 (86%)]	Loss: 0.000256
# ====> Epoch: 24 Average loss: 0.0002
# Train Epoch: 25 [128/1000 (14%)]	Loss: 0.000252
# Train Epoch: 25 [256/1000 (29%)]	Loss: 0.000247
# Train Epoch: 25 [384/1000 (43%)]	Loss: 0.000263
# Train Epoch: 25 [512/1000 (57%)]	Loss: 0.000244
# Train Epoch: 25 [640/1000 (71%)]	Loss: 0.000245
# Train Epoch: 25 [768/1000 (86%)]	Loss: 0.000261
# ====> Epoch: 25 Average loss: 0.0002
# Train Epoch: 26 [128/1000 (14%)]	Loss: 0.000244
# Train Epoch: 26 [256/1000 (29%)]	Loss: 0.000252
# Train Epoch: 26 [384/1000 (43%)]	Loss: 0.000248
# Train Epoch: 26 [512/1000 (57%)]	Loss: 0.000239
# Train Epoch: 26 [640/1000 (71%)]	Loss: 0.000232
# Train Epoch: 26 [768/1000 (86%)]	Loss: 0.000252
# ====> Epoch: 26 Average loss: 0.0002
# Train Epoch: 27 [128/1000 (14%)]	Loss: 0.000248
# Train Epoch: 27 [256/1000 (29%)]	Loss: 0.000233
# Train Epoch: 27 [384/1000 (43%)]	Loss: 0.000239
# Train Epoch: 27 [512/1000 (57%)]	Loss: 0.000240
# Train Epoch: 27 [640/1000 (71%)]	Loss: 0.000252
# Train Epoch: 27 [768/1000 (86%)]	Loss: 0.000240
# ====> Epoch: 27 Average loss: 0.0002
# Train Epoch: 28 [128/1000 (14%)]	Loss: 0.000242
# Train Epoch: 28 [256/1000 (29%)]	Loss: 0.000235
# Train Epoch: 28 [384/1000 (43%)]	Loss: 0.000235
# Train Epoch: 28 [512/1000 (57%)]	Loss: 0.000234
# Train Epoch: 28 [640/1000 (71%)]	Loss: 0.000232
# Train Epoch: 28 [768/1000 (86%)]	Loss: 0.000233
# ====> Epoch: 28 Average loss: 0.0002
# Train Epoch: 29 [128/1000 (14%)]	Loss: 0.000219
# Train Epoch: 29 [256/1000 (29%)]	Loss: 0.000241
# Train Epoch: 29 [384/1000 (43%)]	Loss: 0.000224
# Train Epoch: 29 [512/1000 (57%)]	Loss: 0.000249
# Train Epoch: 29 [640/1000 (71%)]	Loss: 0.000222
# Train Epoch: 29 [768/1000 (86%)]	Loss: 0.000231
# ====> Epoch: 29 Average loss: 0.0002
# Train Epoch: 30 [128/1000 (14%)]	Loss: 0.000226
# Train Epoch: 30 [256/1000 (29%)]	Loss: 0.000214
# Train Epoch: 30 [384/1000 (43%)]	Loss: 0.000221
# Train Epoch: 30 [512/1000 (57%)]	Loss: 0.000230
# Train Epoch: 30 [640/1000 (71%)]	Loss: 0.000229
# Train Epoch: 30 [768/1000 (86%)]	Loss: 0.000240
# ====> Epoch: 30 Average loss: 0.0002
# Train Epoch: 31 [128/1000 (14%)]	Loss: 0.000226
# Train Epoch: 31 [256/1000 (29%)]	Loss: 0.000216
# Train Epoch: 31 [384/1000 (43%)]	Loss: 0.000212
# Train Epoch: 31 [512/1000 (57%)]	Loss: 0.000228
# Train Epoch: 31 [640/1000 (71%)]	Loss: 0.000218
# Train Epoch: 31 [768/1000 (86%)]	Loss: 0.000227
# ====> Epoch: 31 Average loss: 0.0002
# Train Epoch: 32 [128/1000 (14%)]	Loss: 0.000221
# Train Epoch: 32 [256/1000 (29%)]	Loss: 0.000224
# Train Epoch: 32 [384/1000 (43%)]	Loss: 0.000214
# Train Epoch: 32 [512/1000 (57%)]	Loss: 0.000231
# Train Epoch: 32 [640/1000 (71%)]	Loss: 0.000224
# Train Epoch: 32 [768/1000 (86%)]	Loss: 0.000220
# ====> Epoch: 32 Average loss: 0.0002
# Train Epoch: 33 [128/1000 (14%)]	Loss: 0.000223
# Train Epoch: 33 [256/1000 (29%)]	Loss: 0.000200
# Train Epoch: 33 [384/1000 (43%)]	Loss: 0.000212
# Train Epoch: 33 [512/1000 (57%)]	Loss: 0.000210
# Train Epoch: 33 [640/1000 (71%)]	Loss: 0.000214
# Train Epoch: 33 [768/1000 (86%)]	Loss: 0.000215
# ====> Epoch: 33 Average loss: 0.0002
# Train Epoch: 34 [128/1000 (14%)]	Loss: 0.000206
# Train Epoch: 34 [256/1000 (29%)]	Loss: 0.000219
# Train Epoch: 34 [384/1000 (43%)]	Loss: 0.000213
# Train Epoch: 34 [512/1000 (57%)]	Loss: 0.000194
# Train Epoch: 34 [640/1000 (71%)]	Loss: 0.000221
# Train Epoch: 34 [768/1000 (86%)]	Loss: 0.000215
# ====> Epoch: 34 Average loss: 0.0002
# Train Epoch: 35 [128/1000 (14%)]	Loss: 0.000203
# Train Epoch: 35 [256/1000 (29%)]	Loss: 0.000216
# Train Epoch: 35 [384/1000 (43%)]	Loss: 0.000219
# Train Epoch: 35 [512/1000 (57%)]	Loss: 0.000196
# Train Epoch: 35 [640/1000 (71%)]	Loss: 0.000200
# Train Epoch: 35 [768/1000 (86%)]	Loss: 0.000204
# ====> Epoch: 35 Average loss: 0.0002
# Train Epoch: 36 [128/1000 (14%)]	Loss: 0.000197
# Train Epoch: 36 [256/1000 (29%)]	Loss: 0.000202
# Train Epoch: 36 [384/1000 (43%)]	Loss: 0.000200
# Train Epoch: 36 [512/1000 (57%)]	Loss: 0.000204
# Train Epoch: 36 [640/1000 (71%)]	Loss: 0.000202
# Train Epoch: 36 [768/1000 (86%)]	Loss: 0.000203
# ====> Epoch: 36 Average loss: 0.0002
# Train Epoch: 37 [128/1000 (14%)]	Loss: 0.000199
# Train Epoch: 37 [256/1000 (29%)]	Loss: 0.000193
# Train Epoch: 37 [384/1000 (43%)]	Loss: 0.000207
# Train Epoch: 37 [512/1000 (57%)]	Loss: 0.000206
# Train Epoch: 37 [640/1000 (71%)]	Loss: 0.000203
# Train Epoch: 37 [768/1000 (86%)]	Loss: 0.000199
# ====> Epoch: 37 Average loss: 0.0002
# Train Epoch: 38 [128/1000 (14%)]	Loss: 0.000183
# Train Epoch: 38 [256/1000 (29%)]	Loss: 0.000193
# Train Epoch: 38 [384/1000 (43%)]	Loss: 0.000195
# Train Epoch: 38 [512/1000 (57%)]	Loss: 0.000201
# Train Epoch: 38 [640/1000 (71%)]	Loss: 0.000200
# Train Epoch: 38 [768/1000 (86%)]	Loss: 0.000193
# ====> Epoch: 38 Average loss: 0.0002
# Train Epoch: 39 [128/1000 (14%)]	Loss: 0.000191
# Train Epoch: 39 [256/1000 (29%)]	Loss: 0.000189
# Train Epoch: 39 [384/1000 (43%)]	Loss: 0.000195
# Train Epoch: 39 [512/1000 (57%)]	Loss: 0.000187
# Train Epoch: 39 [640/1000 (71%)]	Loss: 0.000189
# Train Epoch: 39 [768/1000 (86%)]	Loss: 0.000190
# ====> Epoch: 39 Average loss: 0.0002
# Train Epoch: 40 [128/1000 (14%)]	Loss: 0.000171
# Train Epoch: 40 [256/1000 (29%)]	Loss: 0.000190
# Train Epoch: 40 [384/1000 (43%)]	Loss: 0.000181
# Train Epoch: 40 [512/1000 (57%)]	Loss: 0.000199
# Train Epoch: 40 [640/1000 (71%)]	Loss: 0.000192
# Train Epoch: 40 [768/1000 (86%)]	Loss: 0.000192
# ====> Epoch: 40 Average loss: 0.0002
# Train Epoch: 41 [128/1000 (14%)]	Loss: 0.000189
# Train Epoch: 41 [256/1000 (29%)]	Loss: 0.000185
# Train Epoch: 41 [384/1000 (43%)]	Loss: 0.000190
# Train Epoch: 41 [512/1000 (57%)]	Loss: 0.000179
# Train Epoch: 41 [640/1000 (71%)]	Loss: 0.000180
# Train Epoch: 41 [768/1000 (86%)]	Loss: 0.000189
# ====> Epoch: 41 Average loss: 0.0002
# Train Epoch: 42 [128/1000 (14%)]	Loss: 0.000177
# Train Epoch: 42 [256/1000 (29%)]	Loss: 0.000185
# Train Epoch: 42 [384/1000 (43%)]	Loss: 0.000184
# Train Epoch: 42 [512/1000 (57%)]	Loss: 0.000190
# Train Epoch: 42 [640/1000 (71%)]	Loss: 0.000176
# Train Epoch: 42 [768/1000 (86%)]	Loss: 0.000184
# ====> Epoch: 42 Average loss: 0.0002
# Train Epoch: 43 [128/1000 (14%)]	Loss: 0.000173
# Train Epoch: 43 [256/1000 (29%)]	Loss: 0.000174
# Train Epoch: 43 [384/1000 (43%)]	Loss: 0.000172
# Train Epoch: 43 [512/1000 (57%)]	Loss: 0.000178
# Train Epoch: 43 [640/1000 (71%)]	Loss: 0.000185
# Train Epoch: 43 [768/1000 (86%)]	Loss: 0.000179
# ====> Epoch: 43 Average loss: 0.0002
# Train Epoch: 44 [128/1000 (14%)]	Loss: 0.000181
# Train Epoch: 44 [256/1000 (29%)]	Loss: 0.000177
# Train Epoch: 44 [384/1000 (43%)]	Loss: 0.000175
# Train Epoch: 44 [512/1000 (57%)]	Loss: 0.000173
# Train Epoch: 44 [640/1000 (71%)]	Loss: 0.000185
# Train Epoch: 44 [768/1000 (86%)]	Loss: 0.000172
# ====> Epoch: 44 Average loss: 0.0002
# Train Epoch: 45 [128/1000 (14%)]	Loss: 0.000160
# Train Epoch: 45 [256/1000 (29%)]	Loss: 0.000172
# Train Epoch: 45 [384/1000 (43%)]	Loss: 0.000176
# Train Epoch: 45 [512/1000 (57%)]	Loss: 0.000182
# Train Epoch: 45 [640/1000 (71%)]	Loss: 0.000191
# Train Epoch: 45 [768/1000 (86%)]	Loss: 0.000170
# ====> Epoch: 45 Average loss: 0.0002
# Train Epoch: 46 [128/1000 (14%)]	Loss: 0.000167
# Train Epoch: 46 [256/1000 (29%)]	Loss: 0.000169
# Train Epoch: 46 [384/1000 (43%)]	Loss: 0.000167
# Train Epoch: 46 [512/1000 (57%)]	Loss: 0.000171
# Train Epoch: 46 [640/1000 (71%)]	Loss: 0.000175
# Train Epoch: 46 [768/1000 (86%)]	Loss: 0.000188
# ====> Epoch: 46 Average loss: 0.0002
# Train Epoch: 47 [128/1000 (14%)]	Loss: 0.000163
# Train Epoch: 47 [256/1000 (29%)]	Loss: 0.000167
# Train Epoch: 47 [384/1000 (43%)]	Loss: 0.000168
# Train Epoch: 47 [512/1000 (57%)]	Loss: 0.000170
# Train Epoch: 47 [640/1000 (71%)]	Loss: 0.000163
# Train Epoch: 47 [768/1000 (86%)]	Loss: 0.000169
# ====> Epoch: 47 Average loss: 0.0001
# Train Epoch: 48 [128/1000 (14%)]	Loss: 0.000164
# Train Epoch: 48 [256/1000 (29%)]	Loss: 0.000166
# Train Epoch: 48 [384/1000 (43%)]	Loss: 0.000164
# Train Epoch: 48 [512/1000 (57%)]	Loss: 0.000163
# Train Epoch: 48 [640/1000 (71%)]	Loss: 0.000166
# Train Epoch: 48 [768/1000 (86%)]	Loss: 0.000171
# ====> Epoch: 48 Average loss: 0.0001
# Train Epoch: 49 [128/1000 (14%)]	Loss: 0.000157
# Train Epoch: 49 [256/1000 (29%)]	Loss: 0.000169
# Train Epoch: 49 [384/1000 (43%)]	Loss: 0.000166
# Train Epoch: 49 [512/1000 (57%)]	Loss: 0.000170
# Train Epoch: 49 [640/1000 (71%)]	Loss: 0.000151
# Train Epoch: 49 [768/1000 (86%)]	Loss: 0.000175
# ====> Epoch: 49 Average loss: 0.0001
# Train Epoch: 50 [128/1000 (14%)]	Loss: 0.000171
# Train Epoch: 50 [256/1000 (29%)]	Loss: 0.000155
# Train Epoch: 50 [384/1000 (43%)]	Loss: 0.000161
# Train Epoch: 50 [512/1000 (57%)]	Loss: 0.000164
# Train Epoch: 50 [640/1000 (71%)]	Loss: 0.000165
# Train Epoch: 50 [768/1000 (86%)]	Loss: 0.000168
# ====> Epoch: 50 Average loss: 0.0001
# Train Epoch: 51 [128/1000 (14%)]	Loss: 0.000151
# Train Epoch: 51 [256/1000 (29%)]	Loss: 0.000158
# Train Epoch: 51 [384/1000 (43%)]	Loss: 0.000170
# Train Epoch: 51 [512/1000 (57%)]	Loss: 0.000156
# Train Epoch: 51 [640/1000 (71%)]	Loss: 0.000163
# Train Epoch: 51 [768/1000 (86%)]	Loss: 0.000157
# ====> Epoch: 51 Average loss: 0.0001
# Train Epoch: 52 [128/1000 (14%)]	Loss: 0.000159
# Train Epoch: 52 [256/1000 (29%)]	Loss: 0.000146
# Train Epoch: 52 [384/1000 (43%)]	Loss: 0.000150
# Train Epoch: 52 [512/1000 (57%)]	Loss: 0.000162
# Train Epoch: 52 [640/1000 (71%)]	Loss: 0.000176
# Train Epoch: 52 [768/1000 (86%)]	Loss: 0.000149
# ====> Epoch: 52 Average loss: 0.0001
# Train Epoch: 53 [128/1000 (14%)]	Loss: 0.000156
# Train Epoch: 53 [256/1000 (29%)]	Loss: 0.000151
# Train Epoch: 53 [384/1000 (43%)]	Loss: 0.000157
# Train Epoch: 53 [512/1000 (57%)]	Loss: 0.000157
# Train Epoch: 53 [640/1000 (71%)]	Loss: 0.000147
# Train Epoch: 53 [768/1000 (86%)]	Loss: 0.000156
# ====> Epoch: 53 Average loss: 0.0001
# Train Epoch: 54 [128/1000 (14%)]	Loss: 0.000155
# Train Epoch: 54 [256/1000 (29%)]	Loss: 0.000156
# Train Epoch: 54 [384/1000 (43%)]	Loss: 0.000160
# Train Epoch: 54 [512/1000 (57%)]	Loss: 0.000148
# Train Epoch: 54 [640/1000 (71%)]	Loss: 0.000156
# Train Epoch: 54 [768/1000 (86%)]	Loss: 0.000152
# ====> Epoch: 54 Average loss: 0.0001
# Train Epoch: 55 [128/1000 (14%)]	Loss: 0.000154
# Train Epoch: 55 [256/1000 (29%)]	Loss: 0.000150
# Train Epoch: 55 [384/1000 (43%)]	Loss: 0.000139
# Train Epoch: 55 [512/1000 (57%)]	Loss: 0.000152
# Train Epoch: 55 [640/1000 (71%)]	Loss: 0.000149
# Train Epoch: 55 [768/1000 (86%)]	Loss: 0.000156
# ====> Epoch: 55 Average loss: 0.0001
# Train Epoch: 56 [128/1000 (14%)]	Loss: 0.000156
# Train Epoch: 56 [256/1000 (29%)]	Loss: 0.000162
# Train Epoch: 56 [384/1000 (43%)]	Loss: 0.000152
# Train Epoch: 56 [512/1000 (57%)]	Loss: 0.000137
# Train Epoch: 56 [640/1000 (71%)]	Loss: 0.000150
# Train Epoch: 56 [768/1000 (86%)]	Loss: 0.000143
# ====> Epoch: 56 Average loss: 0.0001
# Train Epoch: 57 [128/1000 (14%)]	Loss: 0.000145
# Train Epoch: 57 [256/1000 (29%)]	Loss: 0.000148
# Train Epoch: 57 [384/1000 (43%)]	Loss: 0.000145
# Train Epoch: 57 [512/1000 (57%)]	Loss: 0.000148
# Train Epoch: 57 [640/1000 (71%)]	Loss: 0.000141
# Train Epoch: 57 [768/1000 (86%)]	Loss: 0.000152
# ====> Epoch: 57 Average loss: 0.0001
# Train Epoch: 58 [128/1000 (14%)]	Loss: 0.000136
# Train Epoch: 58 [256/1000 (29%)]	Loss: 0.000150
# Train Epoch: 58 [384/1000 (43%)]	Loss: 0.000141
# Train Epoch: 58 [512/1000 (57%)]	Loss: 0.000140
# Train Epoch: 58 [640/1000 (71%)]	Loss: 0.000147
# Train Epoch: 58 [768/1000 (86%)]	Loss: 0.000159
# ====> Epoch: 58 Average loss: 0.0001
# Train Epoch: 59 [128/1000 (14%)]	Loss: 0.000139
# Train Epoch: 59 [256/1000 (29%)]	Loss: 0.000145
# Train Epoch: 59 [384/1000 (43%)]	Loss: 0.000138
# Train Epoch: 59 [512/1000 (57%)]	Loss: 0.000134
# Train Epoch: 59 [640/1000 (71%)]	Loss: 0.000146
# Train Epoch: 59 [768/1000 (86%)]	Loss: 0.000146
# ====> Epoch: 59 Average loss: 0.0001
# Train Epoch: 60 [128/1000 (14%)]	Loss: 0.000143
# Train Epoch: 60 [256/1000 (29%)]	Loss: 0.000142
# Train Epoch: 60 [384/1000 (43%)]	Loss: 0.000150
# Train Epoch: 60 [512/1000 (57%)]	Loss: 0.000144
# Train Epoch: 60 [640/1000 (71%)]	Loss: 0.000123
# Train Epoch: 60 [768/1000 (86%)]	Loss: 0.000149
# ====> Epoch: 60 Average loss: 0.0001
# Train Epoch: 61 [128/1000 (14%)]	Loss: 0.000134
# Train Epoch: 61 [256/1000 (29%)]	Loss: 0.000142
# Train Epoch: 61 [384/1000 (43%)]	Loss: 0.000145
# Train Epoch: 61 [512/1000 (57%)]	Loss: 0.000134
# Train Epoch: 61 [640/1000 (71%)]	Loss: 0.000138
# Train Epoch: 61 [768/1000 (86%)]	Loss: 0.000139
# ====> Epoch: 61 Average loss: 0.0001
# Train Epoch: 62 [128/1000 (14%)]	Loss: 0.000135
# Train Epoch: 62 [256/1000 (29%)]	Loss: 0.000136
# Train Epoch: 62 [384/1000 (43%)]	Loss: 0.000146
# Train Epoch: 62 [512/1000 (57%)]	Loss: 0.000138
# Train Epoch: 62 [640/1000 (71%)]	Loss: 0.000136
# Train Epoch: 62 [768/1000 (86%)]	Loss: 0.000136
# ====> Epoch: 62 Average loss: 0.0001
# Train Epoch: 63 [128/1000 (14%)]	Loss: 0.000133
# Train Epoch: 63 [256/1000 (29%)]	Loss: 0.000133
# Train Epoch: 63 [384/1000 (43%)]	Loss: 0.000135
# Train Epoch: 63 [512/1000 (57%)]	Loss: 0.000130
# Train Epoch: 63 [640/1000 (71%)]	Loss: 0.000135
# Train Epoch: 63 [768/1000 (86%)]	Loss: 0.000143
# ====> Epoch: 63 Average loss: 0.0001
# Train Epoch: 64 [128/1000 (14%)]	Loss: 0.000126
# Train Epoch: 64 [256/1000 (29%)]	Loss: 0.000133
# Train Epoch: 64 [384/1000 (43%)]	Loss: 0.000132
# Train Epoch: 64 [512/1000 (57%)]	Loss: 0.000139
# Train Epoch: 64 [640/1000 (71%)]	Loss: 0.000142
# Train Epoch: 64 [768/1000 (86%)]	Loss: 0.000132
# ====> Epoch: 64 Average loss: 0.0001
# Train Epoch: 65 [128/1000 (14%)]	Loss: 0.000122
# Train Epoch: 65 [256/1000 (29%)]	Loss: 0.000130
# Train Epoch: 65 [384/1000 (43%)]	Loss: 0.000132
# Train Epoch: 65 [512/1000 (57%)]	Loss: 0.000137
# Train Epoch: 65 [640/1000 (71%)]	Loss: 0.000127
# Train Epoch: 65 [768/1000 (86%)]	Loss: 0.000140
# ====> Epoch: 65 Average loss: 0.0001
# Train Epoch: 66 [128/1000 (14%)]	Loss: 0.000133
# Train Epoch: 66 [256/1000 (29%)]	Loss: 0.000126
# Train Epoch: 66 [384/1000 (43%)]	Loss: 0.000136
# Train Epoch: 66 [512/1000 (57%)]	Loss: 0.000128
# Train Epoch: 66 [640/1000 (71%)]	Loss: 0.000126
# Train Epoch: 66 [768/1000 (86%)]	Loss: 0.000129
# ====> Epoch: 66 Average loss: 0.0001
# Train Epoch: 67 [128/1000 (14%)]	Loss: 0.000123
# Train Epoch: 67 [256/1000 (29%)]	Loss: 0.000127
# Train Epoch: 67 [384/1000 (43%)]	Loss: 0.000136
# Train Epoch: 67 [512/1000 (57%)]	Loss: 0.000122
# Train Epoch: 67 [640/1000 (71%)]	Loss: 0.000131
# Train Epoch: 67 [768/1000 (86%)]	Loss: 0.000139
# ====> Epoch: 67 Average loss: 0.0001
# Train Epoch: 68 [128/1000 (14%)]	Loss: 0.000130
# Train Epoch: 68 [256/1000 (29%)]	Loss: 0.000130
# Train Epoch: 68 [384/1000 (43%)]	Loss: 0.000125
# Train Epoch: 68 [512/1000 (57%)]	Loss: 0.000128
# Train Epoch: 68 [640/1000 (71%)]	Loss: 0.000128
# Train Epoch: 68 [768/1000 (86%)]	Loss: 0.000132
# ====> Epoch: 68 Average loss: 0.0001
# Train Epoch: 69 [128/1000 (14%)]	Loss: 0.000121
# Train Epoch: 69 [256/1000 (29%)]	Loss: 0.000128
# Train Epoch: 69 [384/1000 (43%)]	Loss: 0.000138
# Train Epoch: 69 [512/1000 (57%)]	Loss: 0.000125
# Train Epoch: 69 [640/1000 (71%)]	Loss: 0.000126
# Train Epoch: 69 [768/1000 (86%)]	Loss: 0.000132
# ====> Epoch: 69 Average loss: 0.0001
# Train Epoch: 70 [128/1000 (14%)]	Loss: 0.000120
# Train Epoch: 70 [256/1000 (29%)]	Loss: 0.000129
# Train Epoch: 70 [384/1000 (43%)]	Loss: 0.000129
# Train Epoch: 70 [512/1000 (57%)]	Loss: 0.000131
# Train Epoch: 70 [640/1000 (71%)]	Loss: 0.000121
# Train Epoch: 70 [768/1000 (86%)]	Loss: 0.000128
# ====> Epoch: 70 Average loss: 0.0001
# Train Epoch: 71 [128/1000 (14%)]	Loss: 0.000125
# Train Epoch: 71 [256/1000 (29%)]	Loss: 0.000123
# Train Epoch: 71 [384/1000 (43%)]	Loss: 0.000122
# Train Epoch: 71 [512/1000 (57%)]	Loss: 0.000120
# Train Epoch: 71 [640/1000 (71%)]	Loss: 0.000124
# Train Epoch: 71 [768/1000 (86%)]	Loss: 0.000131
# ====> Epoch: 71 Average loss: 0.0001
# Train Epoch: 72 [128/1000 (14%)]	Loss: 0.000128
# Train Epoch: 72 [256/1000 (29%)]	Loss: 0.000119
# Train Epoch: 72 [384/1000 (43%)]	Loss: 0.000133
# Train Epoch: 72 [512/1000 (57%)]	Loss: 0.000121
# Train Epoch: 72 [640/1000 (71%)]	Loss: 0.000127
# Train Epoch: 72 [768/1000 (86%)]	Loss: 0.000123
# ====> Epoch: 72 Average loss: 0.0001
# Train Epoch: 73 [128/1000 (14%)]	Loss: 0.000127
# Train Epoch: 73 [256/1000 (29%)]	Loss: 0.000120
# Train Epoch: 73 [384/1000 (43%)]	Loss: 0.000122
# Train Epoch: 73 [512/1000 (57%)]	Loss: 0.000113
# Train Epoch: 73 [640/1000 (71%)]	Loss: 0.000122
# Train Epoch: 73 [768/1000 (86%)]	Loss: 0.000126
# ====> Epoch: 73 Average loss: 0.0001
# Train Epoch: 74 [128/1000 (14%)]	Loss: 0.000124
# Train Epoch: 74 [256/1000 (29%)]	Loss: 0.000124
# Train Epoch: 74 [384/1000 (43%)]	Loss: 0.000121
# Train Epoch: 74 [512/1000 (57%)]	Loss: 0.000113
# Train Epoch: 74 [640/1000 (71%)]	Loss: 0.000120
# Train Epoch: 74 [768/1000 (86%)]	Loss: 0.000118
# ====> Epoch: 74 Average loss: 0.0001
# Train Epoch: 75 [128/1000 (14%)]	Loss: 0.000124
# Train Epoch: 75 [256/1000 (29%)]	Loss: 0.000119
# Train Epoch: 75 [384/1000 (43%)]	Loss: 0.000118
# Train Epoch: 75 [512/1000 (57%)]	Loss: 0.000122
# Train Epoch: 75 [640/1000 (71%)]	Loss: 0.000111
# Train Epoch: 75 [768/1000 (86%)]	Loss: 0.000117
# ====> Epoch: 75 Average loss: 0.0001
# Train Epoch: 76 [128/1000 (14%)]	Loss: 0.000122
# Train Epoch: 76 [256/1000 (29%)]	Loss: 0.000111
# Train Epoch: 76 [384/1000 (43%)]	Loss: 0.000118
# Train Epoch: 76 [512/1000 (57%)]	Loss: 0.000113
# Train Epoch: 76 [640/1000 (71%)]	Loss: 0.000126
# Train Epoch: 76 [768/1000 (86%)]	Loss: 0.000127
# ====> Epoch: 76 Average loss: 0.0001
# Train Epoch: 77 [128/1000 (14%)]	Loss: 0.000121
# Train Epoch: 77 [256/1000 (29%)]	Loss: 0.000120
# Train Epoch: 77 [384/1000 (43%)]	Loss: 0.000109
# Train Epoch: 77 [512/1000 (57%)]	Loss: 0.000111
# Train Epoch: 77 [640/1000 (71%)]	Loss: 0.000120
# Train Epoch: 77 [768/1000 (86%)]	Loss: 0.000125
# ====> Epoch: 77 Average loss: 0.0001
# Train Epoch: 78 [128/1000 (14%)]	Loss: 0.000120
# Train Epoch: 78 [256/1000 (29%)]	Loss: 0.000102
# Train Epoch: 78 [384/1000 (43%)]	Loss: 0.000119
# Train Epoch: 78 [512/1000 (57%)]	Loss: 0.000116
# Train Epoch: 78 [640/1000 (71%)]	Loss: 0.000113
# Train Epoch: 78 [768/1000 (86%)]	Loss: 0.000119
# ====> Epoch: 78 Average loss: 0.0001
# Train Epoch: 79 [128/1000 (14%)]	Loss: 0.000111
# Train Epoch: 79 [256/1000 (29%)]	Loss: 0.000114
# Train Epoch: 79 [384/1000 (43%)]	Loss: 0.000124
# Train Epoch: 79 [512/1000 (57%)]	Loss: 0.000114
# Train Epoch: 79 [640/1000 (71%)]	Loss: 0.000116
# Train Epoch: 79 [768/1000 (86%)]	Loss: 0.000122
# ====> Epoch: 79 Average loss: 0.0001
# Train Epoch: 80 [128/1000 (14%)]	Loss: 0.000112
# Train Epoch: 80 [256/1000 (29%)]	Loss: 0.000116
# Train Epoch: 80 [384/1000 (43%)]	Loss: 0.000114
# Train Epoch: 80 [512/1000 (57%)]	Loss: 0.000122
# Train Epoch: 80 [640/1000 (71%)]	Loss: 0.000114
# Train Epoch: 80 [768/1000 (86%)]	Loss: 0.000114
# ====> Epoch: 80 Average loss: 0.0001
# Train Epoch: 81 [128/1000 (14%)]	Loss: 0.000113
# Train Epoch: 81 [256/1000 (29%)]	Loss: 0.000110
# Train Epoch: 81 [384/1000 (43%)]	Loss: 0.000123
# Train Epoch: 81 [512/1000 (57%)]	Loss: 0.000115
# Train Epoch: 81 [640/1000 (71%)]	Loss: 0.000115
# Train Epoch: 81 [768/1000 (86%)]	Loss: 0.000107
# ====> Epoch: 81 Average loss: 0.0001
# Train Epoch: 82 [128/1000 (14%)]	Loss: 0.000114
# Train Epoch: 82 [256/1000 (29%)]	Loss: 0.000114
# Train Epoch: 82 [384/1000 (43%)]	Loss: 0.000104
# Train Epoch: 82 [512/1000 (57%)]	Loss: 0.000118
# Train Epoch: 82 [640/1000 (71%)]	Loss: 0.000112
# Train Epoch: 82 [768/1000 (86%)]	Loss: 0.000109
# ====> Epoch: 82 Average loss: 0.0001
# Train Epoch: 83 [128/1000 (14%)]	Loss: 0.000099
# Train Epoch: 83 [256/1000 (29%)]	Loss: 0.000105
# Train Epoch: 83 [384/1000 (43%)]	Loss: 0.000116
# Train Epoch: 83 [512/1000 (57%)]	Loss: 0.000115
# Train Epoch: 83 [640/1000 (71%)]	Loss: 0.000109
# Train Epoch: 83 [768/1000 (86%)]	Loss: 0.000109
# ====> Epoch: 83 Average loss: 0.0001
# Train Epoch: 84 [128/1000 (14%)]	Loss: 0.000112
# Train Epoch: 84 [256/1000 (29%)]	Loss: 0.000108
# Train Epoch: 84 [384/1000 (43%)]	Loss: 0.000111
# Train Epoch: 84 [512/1000 (57%)]	Loss: 0.000100
# Train Epoch: 84 [640/1000 (71%)]	Loss: 0.000110
# Train Epoch: 84 [768/1000 (86%)]	Loss: 0.000115
# ====> Epoch: 84 Average loss: 0.0001
# Train Epoch: 85 [128/1000 (14%)]	Loss: 0.000105
# Train Epoch: 85 [256/1000 (29%)]	Loss: 0.000105
# Train Epoch: 85 [384/1000 (43%)]	Loss: 0.000104
# Train Epoch: 85 [512/1000 (57%)]	Loss: 0.000107
# Train Epoch: 85 [640/1000 (71%)]	Loss: 0.000113
# Train Epoch: 85 [768/1000 (86%)]	Loss: 0.000116
# ====> Epoch: 85 Average loss: 0.0001
# Train Epoch: 86 [128/1000 (14%)]	Loss: 0.000110
# Train Epoch: 86 [256/1000 (29%)]	Loss: 0.000107
# Train Epoch: 86 [384/1000 (43%)]	Loss: 0.000104
# Train Epoch: 86 [512/1000 (57%)]	Loss: 0.000095
# Train Epoch: 86 [640/1000 (71%)]	Loss: 0.000110
# Train Epoch: 86 [768/1000 (86%)]	Loss: 0.000118
# ====> Epoch: 86 Average loss: 0.0001
# Train Epoch: 87 [128/1000 (14%)]	Loss: 0.000112
# Train Epoch: 87 [256/1000 (29%)]	Loss: 0.000102
# Train Epoch: 87 [384/1000 (43%)]	Loss: 0.000103
# Train Epoch: 87 [512/1000 (57%)]	Loss: 0.000111
# Train Epoch: 87 [640/1000 (71%)]	Loss: 0.000100
# Train Epoch: 87 [768/1000 (86%)]	Loss: 0.000107
# ====> Epoch: 87 Average loss: 0.0001
# Train Epoch: 88 [128/1000 (14%)]	Loss: 0.000104
# Train Epoch: 88 [256/1000 (29%)]	Loss: 0.000107
# Train Epoch: 88 [384/1000 (43%)]	Loss: 0.000106
# Train Epoch: 88 [512/1000 (57%)]	Loss: 0.000090
# Train Epoch: 88 [640/1000 (71%)]	Loss: 0.000110
# Train Epoch: 88 [768/1000 (86%)]	Loss: 0.000106
# ====> Epoch: 88 Average loss: 0.0001
# Train Epoch: 89 [128/1000 (14%)]	Loss: 0.000104
# Train Epoch: 89 [256/1000 (29%)]	Loss: 0.000103
# Train Epoch: 89 [384/1000 (43%)]	Loss: 0.000100
# Train Epoch: 89 [512/1000 (57%)]	Loss: 0.000099
# Train Epoch: 89 [640/1000 (71%)]	Loss: 0.000113
# Train Epoch: 89 [768/1000 (86%)]	Loss: 0.000108
# ====> Epoch: 89 Average loss: 0.0001
# Train Epoch: 90 [128/1000 (14%)]	Loss: 0.000101
# Train Epoch: 90 [256/1000 (29%)]	Loss: 0.000102
# Train Epoch: 90 [384/1000 (43%)]	Loss: 0.000103
# Train Epoch: 90 [512/1000 (57%)]	Loss: 0.000107
# Train Epoch: 90 [640/1000 (71%)]	Loss: 0.000109
# Train Epoch: 90 [768/1000 (86%)]	Loss: 0.000097
# ====> Epoch: 90 Average loss: 0.0001
# Train Epoch: 91 [128/1000 (14%)]	Loss: 0.000109
# Train Epoch: 91 [256/1000 (29%)]	Loss: 0.000102
# Train Epoch: 91 [384/1000 (43%)]	Loss: 0.000112
# Train Epoch: 91 [512/1000 (57%)]	Loss: 0.000103
# Train Epoch: 91 [640/1000 (71%)]	Loss: 0.000098
# Train Epoch: 91 [768/1000 (86%)]	Loss: 0.000097
# ====> Epoch: 91 Average loss: 0.0001
# Train Epoch: 92 [128/1000 (14%)]	Loss: 0.000105
# Train Epoch: 92 [256/1000 (29%)]	Loss: 0.000099
# Train Epoch: 92 [384/1000 (43%)]	Loss: 0.000104
# Train Epoch: 92 [512/1000 (57%)]	Loss: 0.000100
# Train Epoch: 92 [640/1000 (71%)]	Loss: 0.000101
# Train Epoch: 92 [768/1000 (86%)]	Loss: 0.000107
# ====> Epoch: 92 Average loss: 0.0001
# Train Epoch: 93 [128/1000 (14%)]	Loss: 0.000102
# Train Epoch: 93 [256/1000 (29%)]	Loss: 0.000098
# Train Epoch: 93 [384/1000 (43%)]	Loss: 0.000100
# Train Epoch: 93 [512/1000 (57%)]	Loss: 0.000103
# Train Epoch: 93 [640/1000 (71%)]	Loss: 0.000108
# Train Epoch: 93 [768/1000 (86%)]	Loss: 0.000103
# ====> Epoch: 93 Average loss: 0.0001
# Train Epoch: 94 [128/1000 (14%)]	Loss: 0.000100
# Train Epoch: 94 [256/1000 (29%)]	Loss: 0.000100
# Train Epoch: 94 [384/1000 (43%)]	Loss: 0.000094
# Train Epoch: 94 [512/1000 (57%)]	Loss: 0.000101
# Train Epoch: 94 [640/1000 (71%)]	Loss: 0.000100
# Train Epoch: 94 [768/1000 (86%)]	Loss: 0.000113
# ====> Epoch: 94 Average loss: 0.0001
# Train Epoch: 95 [128/1000 (14%)]	Loss: 0.000102
# Train Epoch: 95 [256/1000 (29%)]	Loss: 0.000099
# Train Epoch: 95 [384/1000 (43%)]	Loss: 0.000098
# Train Epoch: 95 [512/1000 (57%)]	Loss: 0.000099
# Train Epoch: 95 [640/1000 (71%)]	Loss: 0.000099
# Train Epoch: 95 [768/1000 (86%)]	Loss: 0.000097
# ====> Epoch: 95 Average loss: 0.0001
# Train Epoch: 96 [128/1000 (14%)]	Loss: 0.000094
# Train Epoch: 96 [256/1000 (29%)]	Loss: 0.000102
# Train Epoch: 96 [384/1000 (43%)]	Loss: 0.000094
# Train Epoch: 96 [512/1000 (57%)]	Loss: 0.000097
# Train Epoch: 96 [640/1000 (71%)]	Loss: 0.000106
# Train Epoch: 96 [768/1000 (86%)]	Loss: 0.000098
# ====> Epoch: 96 Average loss: 0.0001
# Train Epoch: 97 [128/1000 (14%)]	Loss: 0.000098
# Train Epoch: 97 [256/1000 (29%)]	Loss: 0.000108
# Train Epoch: 97 [384/1000 (43%)]	Loss: 0.000094
# Train Epoch: 97 [512/1000 (57%)]	Loss: 0.000098
# Train Epoch: 97 [640/1000 (71%)]	Loss: 0.000100
# Train Epoch: 97 [768/1000 (86%)]	Loss: 0.000102
# ====> Epoch: 97 Average loss: 0.0001
# Train Epoch: 98 [128/1000 (14%)]	Loss: 0.000090
# Train Epoch: 98 [256/1000 (29%)]	Loss: 0.000090
# Train Epoch: 98 [384/1000 (43%)]	Loss: 0.000092
# Train Epoch: 98 [512/1000 (57%)]	Loss: 0.000102
# Train Epoch: 98 [640/1000 (71%)]	Loss: 0.000100
# Train Epoch: 98 [768/1000 (86%)]	Loss: 0.000103
# ====> Epoch: 98 Average loss: 0.0001
# Train Epoch: 99 [128/1000 (14%)]	Loss: 0.000100
# Train Epoch: 99 [256/1000 (29%)]	Loss: 0.000096
# Train Epoch: 99 [384/1000 (43%)]	Loss: 0.000091
# Train Epoch: 99 [512/1000 (57%)]	Loss: 0.000103
# Train Epoch: 99 [640/1000 (71%)]	Loss: 0.000093
# Train Epoch: 99 [768/1000 (86%)]	Loss: 0.000090
# ====> Epoch: 99 Average loss: 0.0001
# Train Epoch: 100 [128/1000 (14%)]	Loss: 0.000099
# Train Epoch: 100 [256/1000 (29%)]	Loss: 0.000095
# Train Epoch: 100 [384/1000 (43%)]	Loss: 0.000093
# Train Epoch: 100 [512/1000 (57%)]	Loss: 0.000097
# Train Epoch: 100 [640/1000 (71%)]	Loss: 0.000090
# Train Epoch: 100 [768/1000 (86%)]	Loss: 0.000098
# ====> Epoch: 100 Average loss: 0.0001
# Train Epoch: 101 [128/1000 (14%)]	Loss: 0.000093
# Train Epoch: 101 [256/1000 (29%)]	Loss: 0.000091
# Train Epoch: 101 [384/1000 (43%)]	Loss: 0.000095
# Train Epoch: 101 [512/1000 (57%)]	Loss: 0.000095
# Train Epoch: 101 [640/1000 (71%)]	Loss: 0.000089
# Train Epoch: 101 [768/1000 (86%)]	Loss: 0.000098
# ====> Epoch: 101 Average loss: 0.0001
# Train Epoch: 102 [128/1000 (14%)]	Loss: 0.000091
# Train Epoch: 102 [256/1000 (29%)]	Loss: 0.000093
# Train Epoch: 102 [384/1000 (43%)]	Loss: 0.000096
# Train Epoch: 102 [512/1000 (57%)]	Loss: 0.000089
# Train Epoch: 102 [640/1000 (71%)]	Loss: 0.000088
# Train Epoch: 102 [768/1000 (86%)]	Loss: 0.000095
# ====> Epoch: 102 Average loss: 0.0001
# Train Epoch: 103 [128/1000 (14%)]	Loss: 0.000091
# Train Epoch: 103 [256/1000 (29%)]	Loss: 0.000091
# Train Epoch: 103 [384/1000 (43%)]	Loss: 0.000092
# Train Epoch: 103 [512/1000 (57%)]	Loss: 0.000085
# Train Epoch: 103 [640/1000 (71%)]	Loss: 0.000094
# Train Epoch: 103 [768/1000 (86%)]	Loss: 0.000094
# ====> Epoch: 103 Average loss: 0.0001
# Train Epoch: 104 [128/1000 (14%)]	Loss: 0.000090
# Train Epoch: 104 [256/1000 (29%)]	Loss: 0.000092
# Train Epoch: 104 [384/1000 (43%)]	Loss: 0.000088
# Train Epoch: 104 [512/1000 (57%)]	Loss: 0.000086
# Train Epoch: 104 [640/1000 (71%)]	Loss: 0.000089
# Train Epoch: 104 [768/1000 (86%)]	Loss: 0.000090
# ====> Epoch: 104 Average loss: 0.0001
# Train Epoch: 105 [128/1000 (14%)]	Loss: 0.000093
# Train Epoch: 105 [256/1000 (29%)]	Loss: 0.000086
# Train Epoch: 105 [384/1000 (43%)]	Loss: 0.000091
# Train Epoch: 105 [512/1000 (57%)]	Loss: 0.000083
# Train Epoch: 105 [640/1000 (71%)]	Loss: 0.000092
# Train Epoch: 105 [768/1000 (86%)]	Loss: 0.000093
# ====> Epoch: 105 Average loss: 0.0001
# Train Epoch: 106 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 106 [256/1000 (29%)]	Loss: 0.000085
# Train Epoch: 106 [384/1000 (43%)]	Loss: 0.000092
# Train Epoch: 106 [512/1000 (57%)]	Loss: 0.000094
# Train Epoch: 106 [640/1000 (71%)]	Loss: 0.000098
# Train Epoch: 106 [768/1000 (86%)]	Loss: 0.000089
# ====> Epoch: 106 Average loss: 0.0001
# Train Epoch: 107 [128/1000 (14%)]	Loss: 0.000078
# Train Epoch: 107 [256/1000 (29%)]	Loss: 0.000090
# Train Epoch: 107 [384/1000 (43%)]	Loss: 0.000093
# Train Epoch: 107 [512/1000 (57%)]	Loss: 0.000097
# Train Epoch: 107 [640/1000 (71%)]	Loss: 0.000092
# Train Epoch: 107 [768/1000 (86%)]	Loss: 0.000092
# ====> Epoch: 107 Average loss: 0.0001
# Train Epoch: 108 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 108 [256/1000 (29%)]	Loss: 0.000085
# Train Epoch: 108 [384/1000 (43%)]	Loss: 0.000088
# Train Epoch: 108 [512/1000 (57%)]	Loss: 0.000095
# Train Epoch: 108 [640/1000 (71%)]	Loss: 0.000093
# Train Epoch: 108 [768/1000 (86%)]	Loss: 0.000089
# ====> Epoch: 108 Average loss: 0.0001
# Train Epoch: 109 [128/1000 (14%)]	Loss: 0.000093
# Train Epoch: 109 [256/1000 (29%)]	Loss: 0.000088
# Train Epoch: 109 [384/1000 (43%)]	Loss: 0.000088
# Train Epoch: 109 [512/1000 (57%)]	Loss: 0.000095
# Train Epoch: 109 [640/1000 (71%)]	Loss: 0.000086
# Train Epoch: 109 [768/1000 (86%)]	Loss: 0.000086
# ====> Epoch: 109 Average loss: 0.0001
# Train Epoch: 110 [128/1000 (14%)]	Loss: 0.000083
# Train Epoch: 110 [256/1000 (29%)]	Loss: 0.000084
# Train Epoch: 110 [384/1000 (43%)]	Loss: 0.000091
# Train Epoch: 110 [512/1000 (57%)]	Loss: 0.000086
# Train Epoch: 110 [640/1000 (71%)]	Loss: 0.000089
# Train Epoch: 110 [768/1000 (86%)]	Loss: 0.000091
# ====> Epoch: 110 Average loss: 0.0001
# Train Epoch: 111 [128/1000 (14%)]	Loss: 0.000088
# Train Epoch: 111 [256/1000 (29%)]	Loss: 0.000077
# Train Epoch: 111 [384/1000 (43%)]	Loss: 0.000087
# Train Epoch: 111 [512/1000 (57%)]	Loss: 0.000090
# Train Epoch: 111 [640/1000 (71%)]	Loss: 0.000092
# Train Epoch: 111 [768/1000 (86%)]	Loss: 0.000095
# ====> Epoch: 111 Average loss: 0.0001
# Train Epoch: 112 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 112 [256/1000 (29%)]	Loss: 0.000086
# Train Epoch: 112 [384/1000 (43%)]	Loss: 0.000086
# Train Epoch: 112 [512/1000 (57%)]	Loss: 0.000092
# Train Epoch: 112 [640/1000 (71%)]	Loss: 0.000090
# Train Epoch: 112 [768/1000 (86%)]	Loss: 0.000082
# ====> Epoch: 112 Average loss: 0.0001
# Train Epoch: 113 [128/1000 (14%)]	Loss: 0.000083
# Train Epoch: 113 [256/1000 (29%)]	Loss: 0.000075
# Train Epoch: 113 [384/1000 (43%)]	Loss: 0.000087
# Train Epoch: 113 [512/1000 (57%)]	Loss: 0.000088
# Train Epoch: 113 [640/1000 (71%)]	Loss: 0.000088
# Train Epoch: 113 [768/1000 (86%)]	Loss: 0.000087
# ====> Epoch: 113 Average loss: 0.0001
# Train Epoch: 114 [128/1000 (14%)]	Loss: 0.000081
# Train Epoch: 114 [256/1000 (29%)]	Loss: 0.000080
# Train Epoch: 114 [384/1000 (43%)]	Loss: 0.000081
# Train Epoch: 114 [512/1000 (57%)]	Loss: 0.000083
# Train Epoch: 114 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 114 [768/1000 (86%)]	Loss: 0.000094
# ====> Epoch: 114 Average loss: 0.0001
# Train Epoch: 115 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 115 [256/1000 (29%)]	Loss: 0.000080
# Train Epoch: 115 [384/1000 (43%)]	Loss: 0.000087
# Train Epoch: 115 [512/1000 (57%)]	Loss: 0.000083
# Train Epoch: 115 [640/1000 (71%)]	Loss: 0.000084
# Train Epoch: 115 [768/1000 (86%)]	Loss: 0.000085
# ====> Epoch: 115 Average loss: 0.0001
# Train Epoch: 116 [128/1000 (14%)]	Loss: 0.000087
# Train Epoch: 116 [256/1000 (29%)]	Loss: 0.000087
# Train Epoch: 116 [384/1000 (43%)]	Loss: 0.000076
# Train Epoch: 116 [512/1000 (57%)]	Loss: 0.000080
# Train Epoch: 116 [640/1000 (71%)]	Loss: 0.000081
# Train Epoch: 116 [768/1000 (86%)]	Loss: 0.000084
# ====> Epoch: 116 Average loss: 0.0001
# Train Epoch: 117 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 117 [256/1000 (29%)]	Loss: 0.000086
# Train Epoch: 117 [384/1000 (43%)]	Loss: 0.000083
# Train Epoch: 117 [512/1000 (57%)]	Loss: 0.000075
# Train Epoch: 117 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 117 [768/1000 (86%)]	Loss: 0.000085
# ====> Epoch: 117 Average loss: 0.0001
# Train Epoch: 118 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 118 [256/1000 (29%)]	Loss: 0.000076
# Train Epoch: 118 [384/1000 (43%)]	Loss: 0.000081
# Train Epoch: 118 [512/1000 (57%)]	Loss: 0.000085
# Train Epoch: 118 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 118 [768/1000 (86%)]	Loss: 0.000086
# ====> Epoch: 118 Average loss: 0.0001
# Train Epoch: 119 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 119 [256/1000 (29%)]	Loss: 0.000084
# Train Epoch: 119 [384/1000 (43%)]	Loss: 0.000079
# Train Epoch: 119 [512/1000 (57%)]	Loss: 0.000078
# Train Epoch: 119 [640/1000 (71%)]	Loss: 0.000082
# Train Epoch: 119 [768/1000 (86%)]	Loss: 0.000087
# ====> Epoch: 119 Average loss: 0.0001
# Train Epoch: 120 [128/1000 (14%)]	Loss: 0.000085
# Train Epoch: 120 [256/1000 (29%)]	Loss: 0.000084
# Train Epoch: 120 [384/1000 (43%)]	Loss: 0.000078
# Train Epoch: 120 [512/1000 (57%)]	Loss: 0.000079
# Train Epoch: 120 [640/1000 (71%)]	Loss: 0.000078
# Train Epoch: 120 [768/1000 (86%)]	Loss: 0.000080
# ====> Epoch: 120 Average loss: 0.0001
# Train Epoch: 121 [128/1000 (14%)]	Loss: 0.000083
# Train Epoch: 121 [256/1000 (29%)]	Loss: 0.000073
# Train Epoch: 121 [384/1000 (43%)]	Loss: 0.000086
# Train Epoch: 121 [512/1000 (57%)]	Loss: 0.000081
# Train Epoch: 121 [640/1000 (71%)]	Loss: 0.000078
# Train Epoch: 121 [768/1000 (86%)]	Loss: 0.000083
# ====> Epoch: 121 Average loss: 0.0001
# Train Epoch: 122 [128/1000 (14%)]	Loss: 0.000080
# Train Epoch: 122 [256/1000 (29%)]	Loss: 0.000084
# Train Epoch: 122 [384/1000 (43%)]	Loss: 0.000087
# Train Epoch: 122 [512/1000 (57%)]	Loss: 0.000080
# Train Epoch: 122 [640/1000 (71%)]	Loss: 0.000077
# Train Epoch: 122 [768/1000 (86%)]	Loss: 0.000080
# ====> Epoch: 122 Average loss: 0.0001
# Train Epoch: 123 [128/1000 (14%)]	Loss: 0.000078
# Train Epoch: 123 [256/1000 (29%)]	Loss: 0.000078
# Train Epoch: 123 [384/1000 (43%)]	Loss: 0.000081
# Train Epoch: 123 [512/1000 (57%)]	Loss: 0.000076
# Train Epoch: 123 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 123 [768/1000 (86%)]	Loss: 0.000082
# ====> Epoch: 123 Average loss: 0.0001
# Train Epoch: 124 [128/1000 (14%)]	Loss: 0.000076
# Train Epoch: 124 [256/1000 (29%)]	Loss: 0.000080
# Train Epoch: 124 [384/1000 (43%)]	Loss: 0.000079
# Train Epoch: 124 [512/1000 (57%)]	Loss: 0.000074
# Train Epoch: 124 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 124 [768/1000 (86%)]	Loss: 0.000078
# ====> Epoch: 124 Average loss: 0.0001
# Train Epoch: 125 [128/1000 (14%)]	Loss: 0.000080
# Train Epoch: 125 [256/1000 (29%)]	Loss: 0.000074
# Train Epoch: 125 [384/1000 (43%)]	Loss: 0.000080
# Train Epoch: 125 [512/1000 (57%)]	Loss: 0.000077
# Train Epoch: 125 [640/1000 (71%)]	Loss: 0.000074
# Train Epoch: 125 [768/1000 (86%)]	Loss: 0.000080
# ====> Epoch: 125 Average loss: 0.0001
# Train Epoch: 126 [128/1000 (14%)]	Loss: 0.000082
# Train Epoch: 126 [256/1000 (29%)]	Loss: 0.000077
# Train Epoch: 126 [384/1000 (43%)]	Loss: 0.000071
# Train Epoch: 126 [512/1000 (57%)]	Loss: 0.000075
# Train Epoch: 126 [640/1000 (71%)]	Loss: 0.000075
# Train Epoch: 126 [768/1000 (86%)]	Loss: 0.000080
# ====> Epoch: 126 Average loss: 0.0001
# Train Epoch: 127 [128/1000 (14%)]	Loss: 0.000075
# Train Epoch: 127 [256/1000 (29%)]	Loss: 0.000073
# Train Epoch: 127 [384/1000 (43%)]	Loss: 0.000081
# Train Epoch: 127 [512/1000 (57%)]	Loss: 0.000072
# Train Epoch: 127 [640/1000 (71%)]	Loss: 0.000085
# Train Epoch: 127 [768/1000 (86%)]	Loss: 0.000074
# ====> Epoch: 127 Average loss: 0.0001
# Train Epoch: 128 [128/1000 (14%)]	Loss: 0.000074
# Train Epoch: 128 [256/1000 (29%)]	Loss: 0.000084
# Train Epoch: 128 [384/1000 (43%)]	Loss: 0.000078
# Train Epoch: 128 [512/1000 (57%)]	Loss: 0.000071
# Train Epoch: 128 [640/1000 (71%)]	Loss: 0.000075
# Train Epoch: 128 [768/1000 (86%)]	Loss: 0.000082
# ====> Epoch: 128 Average loss: 0.0001
# Train Epoch: 129 [128/1000 (14%)]	Loss: 0.000076
# Train Epoch: 129 [256/1000 (29%)]	Loss: 0.000075
# Train Epoch: 129 [384/1000 (43%)]	Loss: 0.000078
# Train Epoch: 129 [512/1000 (57%)]	Loss: 0.000076
# Train Epoch: 129 [640/1000 (71%)]	Loss: 0.000073
# Train Epoch: 129 [768/1000 (86%)]	Loss: 0.000083
# ====> Epoch: 129 Average loss: 0.0001
# Train Epoch: 130 [128/1000 (14%)]	Loss: 0.000075
# Train Epoch: 130 [256/1000 (29%)]	Loss: 0.000070
# Train Epoch: 130 [384/1000 (43%)]	Loss: 0.000073
# Train Epoch: 130 [512/1000 (57%)]	Loss: 0.000075
# Train Epoch: 130 [640/1000 (71%)]	Loss: 0.000077
# Train Epoch: 130 [768/1000 (86%)]	Loss: 0.000074
# ====> Epoch: 130 Average loss: 0.0001
# Train Epoch: 131 [128/1000 (14%)]	Loss: 0.000073
# Train Epoch: 131 [256/1000 (29%)]	Loss: 0.000075
# Train Epoch: 131 [384/1000 (43%)]	Loss: 0.000067
# Train Epoch: 131 [512/1000 (57%)]	Loss: 0.000075
# Train Epoch: 131 [640/1000 (71%)]	Loss: 0.000075
# Train Epoch: 131 [768/1000 (86%)]	Loss: 0.000079
# ====> Epoch: 131 Average loss: 0.0001
# Train Epoch: 132 [128/1000 (14%)]	Loss: 0.000072
# Train Epoch: 132 [256/1000 (29%)]	Loss: 0.000071
# Train Epoch: 132 [384/1000 (43%)]	Loss: 0.000071
# Train Epoch: 132 [512/1000 (57%)]	Loss: 0.000076
# Train Epoch: 132 [640/1000 (71%)]	Loss: 0.000072
# Train Epoch: 132 [768/1000 (86%)]	Loss: 0.000080
# ====> Epoch: 132 Average loss: 0.0001
# Train Epoch: 133 [128/1000 (14%)]	Loss: 0.000078
# Train Epoch: 133 [256/1000 (29%)]	Loss: 0.000069
# Train Epoch: 133 [384/1000 (43%)]	Loss: 0.000075
# Train Epoch: 133 [512/1000 (57%)]	Loss: 0.000074
# Train Epoch: 133 [640/1000 (71%)]	Loss: 0.000073
# Train Epoch: 133 [768/1000 (86%)]	Loss: 0.000078
# ====> Epoch: 133 Average loss: 0.0001
# Train Epoch: 134 [128/1000 (14%)]	Loss: 0.000071
# Train Epoch: 134 [256/1000 (29%)]	Loss: 0.000070
# Train Epoch: 134 [384/1000 (43%)]	Loss: 0.000072
# Train Epoch: 134 [512/1000 (57%)]	Loss: 0.000073
# Train Epoch: 134 [640/1000 (71%)]	Loss: 0.000070
# Train Epoch: 134 [768/1000 (86%)]	Loss: 0.000069
# ====> Epoch: 134 Average loss: 0.0001
# Train Epoch: 135 [128/1000 (14%)]	Loss: 0.000070
# Train Epoch: 135 [256/1000 (29%)]	Loss: 0.000077
# Train Epoch: 135 [384/1000 (43%)]	Loss: 0.000069
# Train Epoch: 135 [512/1000 (57%)]	Loss: 0.000072
# Train Epoch: 135 [640/1000 (71%)]	Loss: 0.000070
# Train Epoch: 135 [768/1000 (86%)]	Loss: 0.000077
# ====> Epoch: 135 Average loss: 0.0001
# Train Epoch: 136 [128/1000 (14%)]	Loss: 0.000072
# Train Epoch: 136 [256/1000 (29%)]	Loss: 0.000072
# Train Epoch: 136 [384/1000 (43%)]	Loss: 0.000066
# Train Epoch: 136 [512/1000 (57%)]	Loss: 0.000071
# Train Epoch: 136 [640/1000 (71%)]	Loss: 0.000072
# Train Epoch: 136 [768/1000 (86%)]	Loss: 0.000075
# ====> Epoch: 136 Average loss: 0.0001
# Train Epoch: 137 [128/1000 (14%)]	Loss: 0.000079
# Train Epoch: 137 [256/1000 (29%)]	Loss: 0.000069
# Train Epoch: 137 [384/1000 (43%)]	Loss: 0.000070
# Train Epoch: 137 [512/1000 (57%)]	Loss: 0.000070
# Train Epoch: 137 [640/1000 (71%)]	Loss: 0.000068
# Train Epoch: 137 [768/1000 (86%)]	Loss: 0.000072
# ====> Epoch: 137 Average loss: 0.0001
# Train Epoch: 138 [128/1000 (14%)]	Loss: 0.000074
# Train Epoch: 138 [256/1000 (29%)]	Loss: 0.000067
# Train Epoch: 138 [384/1000 (43%)]	Loss: 0.000067
# Train Epoch: 138 [512/1000 (57%)]	Loss: 0.000071
# Train Epoch: 138 [640/1000 (71%)]	Loss: 0.000071
# Train Epoch: 138 [768/1000 (86%)]	Loss: 0.000067
# ====> Epoch: 138 Average loss: 0.0001
# Train Epoch: 139 [128/1000 (14%)]	Loss: 0.000066
# Train Epoch: 139 [256/1000 (29%)]	Loss: 0.000073
# Train Epoch: 139 [384/1000 (43%)]	Loss: 0.000075
# Train Epoch: 139 [512/1000 (57%)]	Loss: 0.000070
# Train Epoch: 139 [640/1000 (71%)]	Loss: 0.000065
# Train Epoch: 139 [768/1000 (86%)]	Loss: 0.000076
# ====> Epoch: 139 Average loss: 0.0001
# Train Epoch: 140 [128/1000 (14%)]	Loss: 0.000069
# Train Epoch: 140 [256/1000 (29%)]	Loss: 0.000070
# Train Epoch: 140 [384/1000 (43%)]	Loss: 0.000076
# Train Epoch: 140 [512/1000 (57%)]	Loss: 0.000068
# Train Epoch: 140 [640/1000 (71%)]	Loss: 0.000064
# Train Epoch: 140 [768/1000 (86%)]	Loss: 0.000073
# ====> Epoch: 140 Average loss: 0.0001
# Train Epoch: 141 [128/1000 (14%)]	Loss: 0.000066
# Train Epoch: 141 [256/1000 (29%)]	Loss: 0.000068
# Train Epoch: 141 [384/1000 (43%)]	Loss: 0.000067
# Train Epoch: 141 [512/1000 (57%)]	Loss: 0.000074
# Train Epoch: 141 [640/1000 (71%)]	Loss: 0.000074
# Train Epoch: 141 [768/1000 (86%)]	Loss: 0.000067
# ====> Epoch: 141 Average loss: 0.0001
# Train Epoch: 142 [128/1000 (14%)]	Loss: 0.000064
# Train Epoch: 142 [256/1000 (29%)]	Loss: 0.000067
# Train Epoch: 142 [384/1000 (43%)]	Loss: 0.000072
# Train Epoch: 142 [512/1000 (57%)]	Loss: 0.000075
# Train Epoch: 142 [640/1000 (71%)]	Loss: 0.000073
# Train Epoch: 142 [768/1000 (86%)]	Loss: 0.000060
# ====> Epoch: 142 Average loss: 0.0001
# Train Epoch: 143 [128/1000 (14%)]	Loss: 0.000076
# Train Epoch: 143 [256/1000 (29%)]	Loss: 0.000068
# Train Epoch: 143 [384/1000 (43%)]	Loss: 0.000066
# Train Epoch: 143 [512/1000 (57%)]	Loss: 0.000068
# Train Epoch: 143 [640/1000 (71%)]	Loss: 0.000073
# Train Epoch: 143 [768/1000 (86%)]	Loss: 0.000069
# ====> Epoch: 143 Average loss: 0.0001
# Train Epoch: 144 [128/1000 (14%)]	Loss: 0.000070
# Train Epoch: 144 [256/1000 (29%)]	Loss: 0.000072
# Train Epoch: 144 [384/1000 (43%)]	Loss: 0.000073
# Train Epoch: 144 [512/1000 (57%)]	Loss: 0.000063
# Train Epoch: 144 [640/1000 (71%)]	Loss: 0.000064
# Train Epoch: 144 [768/1000 (86%)]	Loss: 0.000072
# ====> Epoch: 144 Average loss: 0.0001
# Train Epoch: 145 [128/1000 (14%)]	Loss: 0.000067
# Train Epoch: 145 [256/1000 (29%)]	Loss: 0.000064
# Train Epoch: 145 [384/1000 (43%)]	Loss: 0.000069
# Train Epoch: 145 [512/1000 (57%)]	Loss: 0.000069
# Train Epoch: 145 [640/1000 (71%)]	Loss: 0.000066
# Train Epoch: 145 [768/1000 (86%)]	Loss: 0.000069
# ====> Epoch: 145 Average loss: 0.0001
# Train Epoch: 146 [128/1000 (14%)]	Loss: 0.000066
# Train Epoch: 146 [256/1000 (29%)]	Loss: 0.000067
# Train Epoch: 146 [384/1000 (43%)]	Loss: 0.000064
# Train Epoch: 146 [512/1000 (57%)]	Loss: 0.000071
# Train Epoch: 146 [640/1000 (71%)]	Loss: 0.000065
# Train Epoch: 146 [768/1000 (86%)]	Loss: 0.000066
# ====> Epoch: 146 Average loss: 0.0001
# Train Epoch: 147 [128/1000 (14%)]	Loss: 0.000068
# Train Epoch: 147 [256/1000 (29%)]	Loss: 0.000067
# Train Epoch: 147 [384/1000 (43%)]	Loss: 0.000069
# Train Epoch: 147 [512/1000 (57%)]	Loss: 0.000065
# Train Epoch: 147 [640/1000 (71%)]	Loss: 0.000072
# Train Epoch: 147 [768/1000 (86%)]	Loss: 0.000064
# ====> Epoch: 147 Average loss: 0.0001
# Train Epoch: 148 [128/1000 (14%)]	Loss: 0.000067
# Train Epoch: 148 [256/1000 (29%)]	Loss: 0.000065
# Train Epoch: 148 [384/1000 (43%)]	Loss: 0.000069
# Train Epoch: 148 [512/1000 (57%)]	Loss: 0.000067
# Train Epoch: 148 [640/1000 (71%)]	Loss: 0.000063
# Train Epoch: 148 [768/1000 (86%)]	Loss: 0.000070
# ====> Epoch: 148 Average loss: 0.0001
# Train Epoch: 149 [128/1000 (14%)]	Loss: 0.000062
# Train Epoch: 149 [256/1000 (29%)]	Loss: 0.000064
# Train Epoch: 149 [384/1000 (43%)]	Loss: 0.000062
# Train Epoch: 149 [512/1000 (57%)]	Loss: 0.000062
# Train Epoch: 149 [640/1000 (71%)]	Loss: 0.000068
# Train Epoch: 149 [768/1000 (86%)]	Loss: 0.000065
# ====> Epoch: 149 Average loss: 0.0001

# %%
def display_images(imgs):

  r = 1
  c = imgs.shape[0]
  fig, axs = plt.subplots(r, c)
  for j in range(c):
    #black and white images
    axs[j].imshow(pytorch_to_numpy(imgs[j, 0,:,:]), cmap='gray')
    axs[j].axis('off')
  plt.show()

def display_ae_images(ae_model, test_imgs):
  n_images = 5
  idx = np.random.randint(0, test_imgs.shape[0], n_images)
  test_imgs = test_imgs[idx,:,:,:]
  print(test_imgs.shape)

  #get output images
  output_imgs = pytorch_to_numpy(ae_model.forward( test_imgs ))
  print(output_imgs.shape)

  r = 2
  c = n_images
  fig, axs = plt.subplots(r, c)
  for j in range(c):
    #black and white images
    axs[0,j].imshow(test_imgs[j, 0,:,:], cmap='gray')
    axs[0,j].axis('off')
    axs[1,j].imshow(output_imgs[j, 0,:,:], cmap='gray')
    axs[1,j].axis('off')
  plt.show()

# %%
test_imgs = next(iter(mnist_train_loader))[0]
display_ae_images(ae_model, test_imgs)
# Out:
# torch.Size([5, 1, 28, 28])
# (5, 1, 28, 28)

# %% [markdown]
# __Question__ Are you satisfied with the results, do they look good ?

# %% [markdown]
# __Your answer:__

# %% [markdown]
# ## 2/ Two simple generative models
#
# In this section, we consider two naÃ¯ve approaches to creating generative models. The general idea is the following:
#
# - train an autoencoder
# - estimate different statistics (average, variance) of the data in the latent space
# - using these statistics, define a model based on a Gaussian distribution
# - generate data with this distribution
#
# We will consider these two situations :
#
# - a multivariate Gaussian distribution with __diagonal covariance matrix__ (each latent component is an independent random variable). This requires the average and variance in each latent component
# - a multivariate Gaussian distribution with __non-diagonal covariance matrix__. This requires the average and covariance matrix of the latent components
#
# Obviously, since this is done _a posteriori_ after training the autoencoder, there is nothing which guarantees that the latent codes do indeed follow a Gaussian distribution. Our goal will be to verify that Variational Autoencoders indeed produce better results than such naÃ¯ve approaches.

# %% [markdown]
# ## 2.0 Defining and generating random Gaussian latent codes
#
# Let $z$ be a latent code and $d$ the dimension of the latent space (called ``z_dim`` in the code). We suppose that the $z$'s follow a multivariate Gaussian distribution, written as:
#
# \begin{equation}
# z \sim \mathcal{N}\left(
# \mu,
# \bf{C}
# \right),
# \end{equation}
# where $\mu$ and $\bf{C}$ are the average vector and covariance matrix of the Gaussian distribution. To define such a generative model, we must therefore determine $\mu$ and $\bf{C}$. Once this is done, we can generate a random Gaussian latent code in the following manner:
#
# \begin{equation}
# z = \mu + {\bf{L}} \varepsilon,
# \end{equation}
# where $\varepsilon$ is a random vector drawn from a multivariate normal distribution ($\mu=0$ and ${\bf{C}} = \text{Id}$), and $\bf{L}$ is the Cholesky decomposition of the positive semi-definite covariance matrix. In other words:
#
# \begin{equation}
# {\bf{C}} = {\bf{L}}{\bf{L}^T}.
# \end{equation}
#
# This gives a simple method of producing a multivariate Gaussian random variable.

# %% [markdown]
# ## 2.1/ A Gaussian model with diagonal covariance
#
# The first naÃ¯ve model is  defined in this first case as:
#
# - $\bf{\mu}=\left[\mu_0, \mu_1, \cdots, \mu_{d-1}\right]^T$
# - $
#   \bf{C} = \begin{pmatrix}
# \sigma_0^2 & 0 & \cdots & 0 \\
# 0 & \sigma_1^2 & \cdots & 0 \\
# \vdots & \ddots & \ddots & \vdots \\
# 0 & 0 & \cdots & \sigma_{d-1}^2
# \end{pmatrix}$
#
# In this situation, therefore, the matrix $\bf{L}$ can be calculated quite simply, as:
# - $
#   \bf{L} = \begin{pmatrix}
# \sigma_0 & 0 & \cdots & 0 \\
# 0 & \sigma_1 & \cdots & 0 \\
# \vdots & \ddots & \ddots & \vdots \\
# 0 & 0 & \cdots & \sigma_{d-1}
# \end{pmatrix}$
#
# In the next cell, calculate the empirical average and variances over a certain number of batches:

# %%
n_batches = np.floor( len(mnist_train_loader.dataset.indices)/batch_size ).astype(int)

z_average = torch.zeros(n_batches,ae_model.z_dim)
z_sigma = torch.zeros(n_batches,ae_model.z_dim)

for batch_idx, (data, _) in enumerate(mnist_train_loader):
  z = ae_model.encoder(data) # (x_dim, z_dim)
  z_average[batch_idx,:] = torch.mean(z, axis=0) # (nB, z_dim)
  z_sigma[batch_idx,:] = torch.std(z, axis=0) # (nB, z_dim)

z_average = torch.mean(z_average, axis=0)
z_sigma = torch.mean(z_sigma, axis=0)

print("Average of latent codes:",z_average)
print("Standard deviation of latent codes:",z_sigma)
# Out:
# Average of latent codes: tensor([  7.4286,  -2.8678,   3.8006,  11.5745,  -9.0337,   2.6398,   1.8115,
#           5.3377,  -6.7495, -10.8863], grad_fn=<MeanBackward1>)
# Standard deviation of latent codes: tensor([ 9.3417,  7.1030,  6.9229,  8.7157,  6.7295,  9.3963,  6.3110, 10.4218,
#          8.2577,  8.5286], grad_fn=<MeanBackward1>)

# %% [markdown]
# Now, in the next cell generate data with this simple generative model using the approach described above. Display these images with the ``display_images`` function.
#
# __NB__ You do not actually have to define the matrix $\bf{L}$ in this case, an element-wise multiplication of two (properly chosen) vectors will suffice. To generate multivariate normal random variables you can use the following Pytorch function:
#
# - ```torch.randn```

# %%
def generate_images_diagonal_gaussian(ae_model, z_average, z_sigma, n_images=5):
  epsilon = torch.randn(n_images, *z_average.shape)
  z_generated = z_average + epsilon * z_sigma
  imgs_generated = ae_model.decoder(z_generated)
  return(imgs_generated)

imgs_generated = generate_images_diagonal_gaussian(ae_model,z_average,z_sigma,n_images=5)
display_images(imgs_generated)

# %% [markdown]
# As you should be able to see, these results are not that good. Let's try a slightly more sophisticated model.

# %% [markdown]
# ## 2.1 Non-diagonal Gaussian model
#
# The second model uses a non-diagonal covariance matrix $\bf{C}$ in the multivariate Gaussian distribution. In the next cell, calculate the average and covariance matrix over several batches of latent codes.
#
# __NB__ You can use the ```torch.cov``` function. Make sure to put the data in the right format for this (see documentation : https://pytorch.org/docs/stable/generated/torch.cov.html).

# %%
n_batches = np.floor( len(mnist_train_loader.dataset.indices)/batch_size ).astype(int)

z_average = torch.zeros(n_batches,ae_model.z_dim)
z_covariance = torch.zeros(n_batches,ae_model.z_dim,ae_model.z_dim)

for batch_idx, (data, _) in enumerate(mnist_train_loader):
  z = ae_model.encoder(data)
  z_average[batch_idx,:] = torch.mean(z, axis=0)
  z_covariance[batch_idx,:,:] = torch.cov(z.T)

z_average = torch.mean(z_average, axis=0)
z_covariance = torch.mean(z_covariance, axis=0)

print("Average of latent codes:",z_average)
print("Covariance matrix of latent codes:",z_covariance)
# Out:
# Average of latent codes: tensor([  7.3117,  -2.8803,   3.7818,  11.4930,  -9.0955,   2.5888,   1.7615,
#           5.1774,  -6.8413, -10.7679], grad_fn=<MeanBackward1>)
# Covariance matrix of latent codes: tensor([[ 88.1348,  -2.3108,  10.2749,  39.3936,  -4.3994,  27.2796,   9.6265,
#           16.6041,   9.2712,   7.0066],
#         [ -2.3108,  50.5397, -11.3605, -27.1274,  -9.6529, -11.4540,  -1.4614,
#           24.6663,  -6.0493,  10.4964],
#         [ 10.2749, -11.3605,  47.9971,  13.8622, -16.1015,  15.1132,  14.8624,
#            8.6728,   4.6563,   0.7769],
#         [ 39.3936, -27.1274,  13.8622,  77.1076,  13.1935,  38.9873,  -3.3746,
#            8.6262,   7.5933, -28.6131],
#         [ -4.3994,  -9.6529, -16.1015,  13.1935,  46.7898,  -5.3271,  -7.3737,
#           11.2652,  -2.9345,   1.7653],
#         [ 27.2796, -11.4540,  15.1132,  38.9873,  -5.3271,  89.6575,  -7.1027,
#            5.8700,  -8.1278, -16.5240],
#         [  9.6265,  -1.4614,  14.8624,  -3.3746,  -7.3737,  -7.1027,  39.5370,
#           23.1796,  12.2812,   1.7078],
#         [ 16.6041,  24.6663,   8.6728,   8.6262,  11.2652,   5.8700,  23.1796,
#          108.2161,   2.4710, -12.8838],
#         [  9.2712,  -6.0493,   4.6563,   7.5933,  -2.9345,  -8.1278,  12.2812,
#            2.4710,  67.8780,   6.7958],
#         [  7.0066,  10.4964,   0.7769, -28.6131,   1.7653, -16.5240,   1.7078,
#          -12.8838,   6.7958,  71.8398]], grad_fn=<MeanBackward1>)

# %% [markdown]
# Now, generate some samples with this distribution. In this case, you will actually have to calculate the Cholesky decomposition and find $\bf{L}$. For this, you can use
#
# - ```torch.linalg.cholesky```
#
# In this model, you will need to carry out matrix multiplication over a batch of latent codes, which is a bit more complicated than the previous naÃ¯ve model (which used element-wise vector multiplication). So you have two options:
#
# - copy the matrix $\bf{L}$ several times and carry out batch matrix multiplication
# - simply loop and carry out normal matrix multiplication to produce each image (this has the disadvantage of not taking advantage of any parallelisation, but it should not matter too much).
#
# In the first case, you can use the following functions:
#
# - ```torch.bmm```
# - ```torch.tile```
#
# Fill in the function to generate images using this model now:

# %%
def generate_images_non_diagonal_gaussian(ae_model, z_average, z_covariance, n_images = 5):
  # calcualte Cholesky decomposition of covariance matrix : C = L L^T
  # Make sure that the first dimension is the batch dimension (with batch size n_images)
  # You can use the torch.unsqueeze function for this
  L = torch.linalg.cholesky(z_covariance).unsqueeze(0).expand(n_images, *z_covariance.shape) # (n_images, z_dim, z_dim)

  epsilon = torch.randn(n_images, z_covariance.shape[0])   # (n_images, z_dim)
  z_generated = z_average + torch.bmm(epsilon.unsqueeze(1), L).squeeze(1)  # (n_images, z_dim)
  imgs_generated = ae_model.decoder(z_generated)
  return(imgs_generated)


imgs_generated = generate_images_non_diagonal_gaussian(ae_model,z_average,z_covariance,n_images = 5)
display_images(imgs_generated)

# %% [markdown]
# You should see some improvement, but we can do better than this. Thus, we turn to the variational autoencoder.

# %% [markdown]
# # 3/ Variational autoencoder
#
# Now, we are going to create an variational autoencoder to carry out __image generation__. Let's first recall the idea of a variational autoencoder
#
# ## Main idea
#
# The main idea is to create an autoencoder whose latent codes follow a certain distribution (a Gaussian distribution in practice). This is done with two tools :
#
# - A specific architecture, where the encoder produces the average and variance of the latent codes
# - A specially designed loss function
#
# Once the VAE is trained, it is possible to sample in the latent space by producing random normal variables and simply decoding.
#
# ## Architecture
#
# The architecture of the VAE model is as follows:
#
# The encoder consists of:
#
# Encoder :
# - Flatten input
# - Dense layer $+$ ReLU
# - Dense layer $+$ ReLU
# - Dense layer (no non-linarity) to produce the average, Dense layer (no non-linarity) to produce the variance (these last two layers are in parallel)
#
# Decoder :
# - Dense layer $+$ ReLU
# - Dense layer $+$ ReLU
# - Dense layer $+$ Sigmoid Activation
# - Reshape, to size $28\times 28\times 1$
#
#
# ## Variational Autoencoder loss
#
# Recall that for the VAE, the loss function is in fact a function to __maximise__. In fact, for implementation, you will see that it is easier to __minimise__ $-\mathcal{L}$.
#
# In the case of an image which is represented by a set of __Bernoulli__ variables (which is relevant for mnist), the original loss function (to maximise) is written :
#
#
# \begin{align}
# \mathcal{L} &= \log\left(p_\theta(x|z)\right) - KL\left( q_\phi(z|x) \; || \; p_\theta(z)\right) \\
#     &= \left(\sum_{i} x_i \log y_i + (1-x_i) \log (1-y_i)\right) - \left(\frac{1}{2} \sum_j \left( \sigma_j^2 + \mu_j^2 - \log \sigma_j^2 -1 \right)\right)
# \end{align}
#
#
# where $i$ is summed over the image pixels, and $j$ is summed over the elements of the latent space. $\sigma_j^2$ is the $j$th element of the latent space variance, and $\mu_j$ is the $j$th element of the latent space mean.
#
# The left part of the loss (reconstruction error) can be implemented simply as the binary cross-entropy between the input x and the output y. Since we are __maximising__ $-$[binary cross-entropy] (look at the formula), this is equivalent to minimising the binary cross-entropy.
#
# For the right part of the equation (KL divergence), you need to implement it manually.
#
# The final loss is the average, over the batch size, of the sum of the reconstruction error (left part) and the KL divergence (right part). Be careful, in the formula, the sums over $i$ and $j$ are over the number of pixels and the number of latent elements, respectively. To achieve a sum rather than an average, you can use ```torch.nn.BCELoss(reduction='sum')()```, and the ```torch.sum()``` functions.
#
# As in the case of the normal autoencoder, you will need to flatten and then reshape the tensors at the beginning/end of the network.

# %%
class VAE(torch.nn.Module ):
  def __init__(self, x_dim, h_dim1, h_dim2, z_dim,n_rows,n_cols,n_channels):
    super(VAE, self).__init__()

    self.n_rows = n_rows
    self.n_cols = n_cols
    self.n_channels = n_channels
    self.n_pixels = (self.n_rows)*(self.n_cols)
    self.z_dim = z_dim

    # encoder part
    self.fc1 = nn.Linear(x_dim, h_dim1)
    self.fc2 = nn.Linear(h_dim1, h_dim2)
    self.fc31 = nn.Linear(h_dim2, z_dim)
    self.fc32 = nn.Linear(h_dim2, z_dim)
    # decoder part
    self.fc4 = nn.Linear(z_dim, h_dim2)
    self.fc5 = nn.Linear(h_dim2, h_dim1)
    self.fc6 = nn.Linear(h_dim1, x_dim)

  def encoder(self, x):
    x = x.view(-1, self.n_pixels * self.n_channels) # Flatten the input to (Batch_size, x_dim)
    h = F.relu(self.fc1(x))
    h = F.relu(self.fc2(h))
    return self.fc31(h), self.fc32(h)

  def decoder(self, z):
    h = F.relu(self.fc4(z))
    h = F.relu(self.fc5(h))
    return F.sigmoid(self.fc6(h)).view(-1, self.n_channels, self.n_rows, self.n_cols)

  def sampling(self, mu, log_var):
    # this function samples a Gaussian distribution, with average (mu) and standard deviation specified (using log_var)
    std = torch.exp(0.5*log_var)
    eps = torch.randn_like(std)
    return eps.mul(std).add_(mu) # return z sample

  def forward(self, x):
    z_mu, z_log_var = self.encoder(x)
    z = self.sampling(z_mu, z_log_var)
    return self.decoder(z), z_mu, z_log_var

  def loss_function(self, x, y, mu, log_var):
    reconstruction_error = nn.BCELoss(reduction='sum')(y, x) # sum over the batch

    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp()) # sum over the batch

    return reconstruction_error + KLD

# %% [markdown]
# Now, create the model (similarly as above)

# %%
# create model
vae_dim_1 = ae_dim_1
vae_dim_2 = ae_dim_2
vae_model = VAE(x_dim=n_pixels, h_dim1= vae_dim_1, h_dim2=vae_dim_2, z_dim=z_dim,n_rows=n_rows,n_cols=n_cols,n_channels=n_channels)
vae_optimizer = optim.Adam(vae_model.parameters())

# %% [markdown]
# Finally, train the model. First modify the training function to the case of the vae.

# %%
def train_vae(vae_model,data_train_loader,epoch):
  train_loss = 0
  for batch_idx, (data, _) in enumerate(data_train_loader):
    vae_optimizer.zero_grad()

    y, z_mu, z_log_var = vae_model(data)
    loss_vae = vae_model.loss_function(data, y, z_mu, z_log_var)
    loss_vae.backward()
    train_loss += loss_vae.item()
    vae_optimizer.step()

    if batch_idx % 100==0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
      epoch, batch_idx * len(data), len(data_train_loader.dataset),
      100. * batch_idx / len(data_train_loader), loss_vae.item() / len(data)))
  print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(data_train_loader.dataset)))

# %%
# now train the model
for epoch in range(0, n_epochs):
  train_vae(vae_model,mnist_train_loader,epoch)
# Out:
# Train Epoch: 0 [0/1000 (0%)]	Loss: 102.306152
# ====> Epoch: 0 Average loss: 91.9349
# Train Epoch: 1 [0/1000 (0%)]	Loss: 104.497894
# ====> Epoch: 1 Average loss: 91.8740
# Train Epoch: 2 [0/1000 (0%)]	Loss: 103.284004
# ====> Epoch: 2 Average loss: 90.7898
# Train Epoch: 3 [0/1000 (0%)]	Loss: 102.423248
# ====> Epoch: 3 Average loss: 91.3875
# Train Epoch: 4 [0/1000 (0%)]	Loss: 97.360123
# ====> Epoch: 4 Average loss: 90.8084
# Train Epoch: 5 [0/1000 (0%)]	Loss: 101.870842
# ====> Epoch: 5 Average loss: 91.1049
# Train Epoch: 6 [0/1000 (0%)]	Loss: 98.600983
# ====> Epoch: 6 Average loss: 91.3308
# Train Epoch: 7 [0/1000 (0%)]	Loss: 101.354805
# ====> Epoch: 7 Average loss: 91.1472
# Train Epoch: 8 [0/1000 (0%)]	Loss: 101.879364
# ====> Epoch: 8 Average loss: 91.3587
# Train Epoch: 9 [0/1000 (0%)]	Loss: 103.262299
# ====> Epoch: 9 Average loss: 90.2974
# Train Epoch: 10 [0/1000 (0%)]	Loss: 101.911003
# ====> Epoch: 10 Average loss: 90.8071
# Train Epoch: 11 [0/1000 (0%)]	Loss: 99.854355
# ====> Epoch: 11 Average loss: 90.5871
# Train Epoch: 12 [0/1000 (0%)]	Loss: 99.585236
# ====> Epoch: 12 Average loss: 90.2537
# Train Epoch: 13 [0/1000 (0%)]	Loss: 101.054108
# ====> Epoch: 13 Average loss: 90.4336
# Train Epoch: 14 [0/1000 (0%)]	Loss: 98.787552
# ====> Epoch: 14 Average loss: 90.0151
# Train Epoch: 15 [0/1000 (0%)]	Loss: 102.298645
# ====> Epoch: 15 Average loss: 89.9760
# Train Epoch: 16 [0/1000 (0%)]	Loss: 103.706802
# ====> Epoch: 16 Average loss: 89.7334
# Train Epoch: 17 [0/1000 (0%)]	Loss: 97.395981
# ====> Epoch: 17 Average loss: 89.9668
# Train Epoch: 18 [0/1000 (0%)]	Loss: 99.012947
# ====> Epoch: 18 Average loss: 89.0681
# Train Epoch: 19 [0/1000 (0%)]	Loss: 103.333290
# ====> Epoch: 19 Average loss: 89.5435
# Train Epoch: 20 [0/1000 (0%)]	Loss: 98.564728
# ====> Epoch: 20 Average loss: 89.7538
# Train Epoch: 21 [0/1000 (0%)]	Loss: 100.599533
# ====> Epoch: 21 Average loss: 89.3610
# Train Epoch: 22 [0/1000 (0%)]	Loss: 102.303299
# ====> Epoch: 22 Average loss: 89.1816
# Train Epoch: 23 [0/1000 (0%)]	Loss: 97.823296
# ====> Epoch: 23 Average loss: 88.8745
# Train Epoch: 24 [0/1000 (0%)]	Loss: 97.340637
# ====> Epoch: 24 Average loss: 88.8238
# Train Epoch: 25 [0/1000 (0%)]	Loss: 100.648102
# ====> Epoch: 25 Average loss: 88.8092
# Train Epoch: 26 [0/1000 (0%)]	Loss: 101.202682
# ====> Epoch: 26 Average loss: 88.9220
# Train Epoch: 27 [0/1000 (0%)]	Loss: 97.636116
# ====> Epoch: 27 Average loss: 88.0634
# Train Epoch: 28 [0/1000 (0%)]	Loss: 100.172890
# ====> Epoch: 28 Average loss: 88.5902
# Train Epoch: 29 [0/1000 (0%)]	Loss: 99.249680
# ====> Epoch: 29 Average loss: 88.5879
# Train Epoch: 30 [0/1000 (0%)]	Loss: 94.739090
# ====> Epoch: 30 Average loss: 88.3517
# Train Epoch: 31 [0/1000 (0%)]	Loss: 98.830368
# ====> Epoch: 31 Average loss: 87.9670
# Train Epoch: 32 [0/1000 (0%)]	Loss: 99.539703
# ====> Epoch: 32 Average loss: 88.1053
# Train Epoch: 33 [0/1000 (0%)]	Loss: 97.324181
# ====> Epoch: 33 Average loss: 87.9788
# Train Epoch: 34 [0/1000 (0%)]	Loss: 96.495476
# ====> Epoch: 34 Average loss: 87.9983
# Train Epoch: 35 [0/1000 (0%)]	Loss: 98.845459
# ====> Epoch: 35 Average loss: 87.9319
# Train Epoch: 36 [0/1000 (0%)]	Loss: 96.175888
# ====> Epoch: 36 Average loss: 87.9318
# Train Epoch: 37 [0/1000 (0%)]	Loss: 100.984459
# ====> Epoch: 37 Average loss: 87.8205
# Train Epoch: 38 [0/1000 (0%)]	Loss: 98.580910
# ====> Epoch: 38 Average loss: 87.7813
# Train Epoch: 39 [0/1000 (0%)]	Loss: 96.681557
# ====> Epoch: 39 Average loss: 87.1742
# Train Epoch: 40 [0/1000 (0%)]	Loss: 96.404305
# ====> Epoch: 40 Average loss: 87.3132
# Train Epoch: 41 [0/1000 (0%)]	Loss: 99.419456
# ====> Epoch: 41 Average loss: 86.8882
# Train Epoch: 42 [0/1000 (0%)]	Loss: 96.759888
# ====> Epoch: 42 Average loss: 87.1440
# Train Epoch: 43 [0/1000 (0%)]	Loss: 96.075142
# ====> Epoch: 43 Average loss: 86.8974
# Train Epoch: 44 [0/1000 (0%)]	Loss: 98.399437
# ====> Epoch: 44 Average loss: 86.5432
# Train Epoch: 45 [0/1000 (0%)]	Loss: 99.956139
# ====> Epoch: 45 Average loss: 86.9412
# Train Epoch: 46 [0/1000 (0%)]	Loss: 95.993919
# ====> Epoch: 46 Average loss: 86.7950
# Train Epoch: 47 [0/1000 (0%)]	Loss: 98.480515
# ====> Epoch: 47 Average loss: 86.4832
# Train Epoch: 48 [0/1000 (0%)]	Loss: 96.606979
# ====> Epoch: 48 Average loss: 86.4919
# Train Epoch: 49 [0/1000 (0%)]	Loss: 96.003746
# ====> Epoch: 49 Average loss: 86.0791
# Train Epoch: 50 [0/1000 (0%)]	Loss: 96.907959
# ====> Epoch: 50 Average loss: 86.4497
# Train Epoch: 51 [0/1000 (0%)]	Loss: 94.948090
# ====> Epoch: 51 Average loss: 85.6494
# Train Epoch: 52 [0/1000 (0%)]	Loss: 96.244278
# ====> Epoch: 52 Average loss: 85.6948
# Train Epoch: 53 [0/1000 (0%)]	Loss: 95.169205
# ====> Epoch: 53 Average loss: 86.0176
# Train Epoch: 54 [0/1000 (0%)]	Loss: 95.751060
# ====> Epoch: 54 Average loss: 85.7130
# Train Epoch: 55 [0/1000 (0%)]	Loss: 97.361633
# ====> Epoch: 55 Average loss: 85.8630
# Train Epoch: 56 [0/1000 (0%)]	Loss: 96.897369
# ====> Epoch: 56 Average loss: 85.6403
# Train Epoch: 57 [0/1000 (0%)]	Loss: 95.918404
# ====> Epoch: 57 Average loss: 85.8799
# Train Epoch: 58 [0/1000 (0%)]	Loss: 94.871689
# ====> Epoch: 58 Average loss: 85.6892
# Train Epoch: 59 [0/1000 (0%)]	Loss: 95.572128
# ====> Epoch: 59 Average loss: 85.5968
# Train Epoch: 60 [0/1000 (0%)]	Loss: 94.166252
# ====> Epoch: 60 Average loss: 85.6380
# Train Epoch: 61 [0/1000 (0%)]	Loss: 94.583870
# ====> Epoch: 61 Average loss: 85.0747
# Train Epoch: 62 [0/1000 (0%)]	Loss: 92.345108
# ====> Epoch: 62 Average loss: 84.8109
# Train Epoch: 63 [0/1000 (0%)]	Loss: 96.312775
# ====> Epoch: 63 Average loss: 85.0337
# Train Epoch: 64 [0/1000 (0%)]	Loss: 94.876335
# ====> Epoch: 64 Average loss: 85.0338
# Train Epoch: 65 [0/1000 (0%)]	Loss: 96.237358
# ====> Epoch: 65 Average loss: 84.8004
# Train Epoch: 66 [0/1000 (0%)]	Loss: 93.372101
# ====> Epoch: 66 Average loss: 84.6511
# Train Epoch: 67 [0/1000 (0%)]	Loss: 93.989403
# ====> Epoch: 67 Average loss: 85.0599
# Train Epoch: 68 [0/1000 (0%)]	Loss: 93.918396
# ====> Epoch: 68 Average loss: 84.4682
# Train Epoch: 69 [0/1000 (0%)]	Loss: 94.053406
# ====> Epoch: 69 Average loss: 84.7158
# Train Epoch: 70 [0/1000 (0%)]	Loss: 97.283279
# ====> Epoch: 70 Average loss: 84.7048
# Train Epoch: 71 [0/1000 (0%)]	Loss: 93.163635
# ====> Epoch: 71 Average loss: 84.4892
# Train Epoch: 72 [0/1000 (0%)]	Loss: 95.498978
# ====> Epoch: 72 Average loss: 84.1414
# Train Epoch: 73 [0/1000 (0%)]	Loss: 96.178131
# ====> Epoch: 73 Average loss: 84.0887
# Train Epoch: 74 [0/1000 (0%)]	Loss: 93.593483
# ====> Epoch: 74 Average loss: 84.2922
# Train Epoch: 75 [0/1000 (0%)]	Loss: 94.325951
# ====> Epoch: 75 Average loss: 84.2920
# Train Epoch: 76 [0/1000 (0%)]	Loss: 96.109802
# ====> Epoch: 76 Average loss: 83.9048
# Train Epoch: 77 [0/1000 (0%)]	Loss: 90.359985
# ====> Epoch: 77 Average loss: 84.0327
# Train Epoch: 78 [0/1000 (0%)]	Loss: 93.295967
# ====> Epoch: 78 Average loss: 83.2126
# Train Epoch: 79 [0/1000 (0%)]	Loss: 90.443649
# ====> Epoch: 79 Average loss: 83.8478
# Train Epoch: 80 [0/1000 (0%)]	Loss: 96.094788
# ====> Epoch: 80 Average loss: 83.6551
# Train Epoch: 81 [0/1000 (0%)]	Loss: 96.757378
# ====> Epoch: 81 Average loss: 83.5744
# Train Epoch: 82 [0/1000 (0%)]	Loss: 94.086044
# ====> Epoch: 82 Average loss: 83.3597
# Train Epoch: 83 [0/1000 (0%)]	Loss: 90.727036
# ====> Epoch: 83 Average loss: 82.9767
# Train Epoch: 84 [0/1000 (0%)]	Loss: 91.971199
# ====> Epoch: 84 Average loss: 82.9622
# Train Epoch: 85 [0/1000 (0%)]	Loss: 90.176796
# ====> Epoch: 85 Average loss: 83.0916
# Train Epoch: 86 [0/1000 (0%)]	Loss: 89.924774
# ====> Epoch: 86 Average loss: 83.2258
# Train Epoch: 87 [0/1000 (0%)]	Loss: 91.705147
# ====> Epoch: 87 Average loss: 82.8671
# Train Epoch: 88 [0/1000 (0%)]	Loss: 92.982025
# ====> Epoch: 88 Average loss: 83.2687
# Train Epoch: 89 [0/1000 (0%)]	Loss: 93.074242
# ====> Epoch: 89 Average loss: 83.1431
# Train Epoch: 90 [0/1000 (0%)]	Loss: 92.171341
# ====> Epoch: 90 Average loss: 82.7351
# Train Epoch: 91 [0/1000 (0%)]	Loss: 91.574707
# ====> Epoch: 91 Average loss: 83.1359
# Train Epoch: 92 [0/1000 (0%)]	Loss: 90.392487
# ====> Epoch: 92 Average loss: 82.8065
# Train Epoch: 93 [0/1000 (0%)]	Loss: 92.105911
# ====> Epoch: 93 Average loss: 82.7257
# Train Epoch: 94 [0/1000 (0%)]	Loss: 92.872772
# ====> Epoch: 94 Average loss: 82.4868
# Train Epoch: 95 [0/1000 (0%)]	Loss: 91.762138
# ====> Epoch: 95 Average loss: 82.3882
# Train Epoch: 96 [0/1000 (0%)]	Loss: 90.406647
# ====> Epoch: 96 Average loss: 82.2963
# Train Epoch: 97 [0/1000 (0%)]	Loss: 94.742966
# ====> Epoch: 97 Average loss: 82.2421
# Train Epoch: 98 [0/1000 (0%)]	Loss: 91.069740
# ====> Epoch: 98 Average loss: 82.6099
# Train Epoch: 99 [0/1000 (0%)]	Loss: 94.201393
# ====> Epoch: 99 Average loss: 82.5355
# Train Epoch: 100 [0/1000 (0%)]	Loss: 90.441559
# ====> Epoch: 100 Average loss: 82.2814
# Train Epoch: 101 [0/1000 (0%)]	Loss: 91.617386
# ====> Epoch: 101 Average loss: 81.8855
# Train Epoch: 102 [0/1000 (0%)]	Loss: 90.202065
# ====> Epoch: 102 Average loss: 81.9906
# Train Epoch: 103 [0/1000 (0%)]	Loss: 88.864258
# ====> Epoch: 103 Average loss: 82.1714
# Train Epoch: 104 [0/1000 (0%)]	Loss: 88.415146
# ====> Epoch: 104 Average loss: 81.8401
# Train Epoch: 105 [0/1000 (0%)]	Loss: 91.765144
# ====> Epoch: 105 Average loss: 82.0233
# Train Epoch: 106 [0/1000 (0%)]	Loss: 89.934761
# ====> Epoch: 106 Average loss: 81.5526
# Train Epoch: 107 [0/1000 (0%)]	Loss: 91.732712
# ====> Epoch: 107 Average loss: 81.9194
# Train Epoch: 108 [0/1000 (0%)]	Loss: 90.126282
# ====> Epoch: 108 Average loss: 81.1422
# Train Epoch: 109 [0/1000 (0%)]	Loss: 92.338562
# ====> Epoch: 109 Average loss: 81.4944
# Train Epoch: 110 [0/1000 (0%)]	Loss: 89.798431
# ====> Epoch: 110 Average loss: 81.4322
# Train Epoch: 111 [0/1000 (0%)]	Loss: 90.376579
# ====> Epoch: 111 Average loss: 81.2485
# Train Epoch: 112 [0/1000 (0%)]	Loss: 89.520996
# ====> Epoch: 112 Average loss: 81.1884
# Train Epoch: 113 [0/1000 (0%)]	Loss: 92.795837
# ====> Epoch: 113 Average loss: 80.6908
# Train Epoch: 114 [0/1000 (0%)]	Loss: 90.767700
# ====> Epoch: 114 Average loss: 81.2476
# Train Epoch: 115 [0/1000 (0%)]	Loss: 91.809685
# ====> Epoch: 115 Average loss: 80.9863
# Train Epoch: 116 [0/1000 (0%)]	Loss: 93.283279
# ====> Epoch: 116 Average loss: 80.9947
# Train Epoch: 117 [0/1000 (0%)]	Loss: 91.207840
# ====> Epoch: 117 Average loss: 81.3690
# Train Epoch: 118 [0/1000 (0%)]	Loss: 91.411041
# ====> Epoch: 118 Average loss: 81.4110
# Train Epoch: 119 [0/1000 (0%)]	Loss: 91.116302
# ====> Epoch: 119 Average loss: 81.1809
# Train Epoch: 120 [0/1000 (0%)]	Loss: 88.460846
# ====> Epoch: 120 Average loss: 81.0384
# Train Epoch: 121 [0/1000 (0%)]	Loss: 91.823074
# ====> Epoch: 121 Average loss: 81.2228
# Train Epoch: 122 [0/1000 (0%)]	Loss: 90.290718
# ====> Epoch: 122 Average loss: 81.0420
# Train Epoch: 123 [0/1000 (0%)]	Loss: 91.510895
# ====> Epoch: 123 Average loss: 80.6547
# Train Epoch: 124 [0/1000 (0%)]	Loss: 92.614685
# ====> Epoch: 124 Average loss: 80.6938
# Train Epoch: 125 [0/1000 (0%)]	Loss: 89.640732
# ====> Epoch: 125 Average loss: 80.7443
# Train Epoch: 126 [0/1000 (0%)]	Loss: 90.156227
# ====> Epoch: 126 Average loss: 80.6022
# Train Epoch: 127 [0/1000 (0%)]	Loss: 88.429291
# ====> Epoch: 127 Average loss: 80.2596
# Train Epoch: 128 [0/1000 (0%)]	Loss: 89.187332
# ====> Epoch: 128 Average loss: 80.1617
# Train Epoch: 129 [0/1000 (0%)]	Loss: 85.891380
# ====> Epoch: 129 Average loss: 79.8981
# Train Epoch: 130 [0/1000 (0%)]	Loss: 89.361816
# ====> Epoch: 130 Average loss: 80.4538
# Train Epoch: 131 [0/1000 (0%)]	Loss: 88.319321
# ====> Epoch: 131 Average loss: 79.9564
# Train Epoch: 132 [0/1000 (0%)]	Loss: 89.741653
# ====> Epoch: 132 Average loss: 80.2481
# Train Epoch: 133 [0/1000 (0%)]	Loss: 89.154602
# ====> Epoch: 133 Average loss: 79.6481
# Train Epoch: 134 [0/1000 (0%)]	Loss: 88.444550
# ====> Epoch: 134 Average loss: 79.6925
# Train Epoch: 135 [0/1000 (0%)]	Loss: 87.351028
# ====> Epoch: 135 Average loss: 79.9142
# Train Epoch: 136 [0/1000 (0%)]	Loss: 88.346115
# ====> Epoch: 136 Average loss: 79.8052
# Train Epoch: 137 [0/1000 (0%)]	Loss: 87.050835
# ====> Epoch: 137 Average loss: 79.5559
# Train Epoch: 138 [0/1000 (0%)]	Loss: 87.755325
# ====> Epoch: 138 Average loss: 79.2235
# Train Epoch: 139 [0/1000 (0%)]	Loss: 89.964699
# ====> Epoch: 139 Average loss: 79.3790
# Train Epoch: 140 [0/1000 (0%)]	Loss: 89.358032
# ====> Epoch: 140 Average loss: 79.9071
# Train Epoch: 141 [0/1000 (0%)]	Loss: 88.434685
# ====> Epoch: 141 Average loss: 79.4317
# Train Epoch: 142 [0/1000 (0%)]	Loss: 86.460709
# ====> Epoch: 142 Average loss: 79.2256
# Train Epoch: 143 [0/1000 (0%)]	Loss: 88.499550
# ====> Epoch: 143 Average loss: 79.3752
# Train Epoch: 144 [0/1000 (0%)]	Loss: 87.402649
# ====> Epoch: 144 Average loss: 79.1056
# Train Epoch: 145 [0/1000 (0%)]	Loss: 88.586113
# ====> Epoch: 145 Average loss: 78.8258
# Train Epoch: 146 [0/1000 (0%)]	Loss: 88.602928
# ====> Epoch: 146 Average loss: 79.0091
# Train Epoch: 147 [0/1000 (0%)]	Loss: 89.741829
# ====> Epoch: 147 Average loss: 79.0045
# Train Epoch: 148 [0/1000 (0%)]	Loss: 85.136124
# ====> Epoch: 148 Average loss: 79.1308
# Train Epoch: 149 [0/1000 (0%)]	Loss: 87.254021
# ====> Epoch: 149 Average loss: 79.4298

# %% [markdown]
# Now, generate some images with the VAE model

# %%
def generate_images_vae(vae_model, n_images = 5):
  epsilon = torch.randn(n_images, vae_model.z_dim)
  imgs_generated = vae_model.decoder(epsilon)
  return(imgs_generated)

imgs_generated = generate_images_vae(vae_model,n_images=5)
display_images(imgs_generated)

# %% [markdown]
# Do you think the results are better ? What difference can you see ? What advantage does the Variational Autoencoder have over the simple autoencoder model, even though the second autoencoder approach has a more complex probabilistic latent model (a full covariance matrix) ?

# %% [markdown]
# ### Statistics of $q_\phi$
#
# Remember, our goal was to create an autoencoder such that the distributions $q_{\phi}(z|x)$ of each input data point in the latent space is a normal distribution, ie such that $\mu=0$ and $\sigma=1$ for all inputs. Let us see if this goal was attained.
#
# For this, take a batch of test images, and calculate the vectors $\mu=0$ and $\sigma=1$ of these images (recall that they should be 0 and 1). Now,use a 2D scatter plot on any two of the latent coordinates to visualise the values of $\mu$ and $\sigma$ (you can try several different combinations of the latent coordinates).
#
# You will need to use ```detach().numpy()``` to plot these values.

# %%
def display_vae_images(vae_model, test_imgs):
    n_images = 5
    idx = np.random.randint(0, test_imgs.shape[0], n_images)
    test_imgs = test_imgs[idx,:,:,:]
    print(test_imgs.shape)
    
    #get output images
    output_imgs = pytorch_to_numpy(vae_model.forward( test_imgs )[0])
    print(output_imgs.shape)
    
    r = 2
    c = n_images
    fig, axs = plt.subplots(r, c)
    for j in range(c):
        #black and white images
        axs[0,j].imshow(test_imgs[j, 0,:,:], cmap='gray')
        axs[0,j].axis('off')
        axs[1,j].imshow(output_imgs[j, 0,:,:], cmap='gray')
        axs[1,j].axis('off')
    plt.show()

test_imgs = next(iter(mnist_train_loader))[0]
display_vae_images(vae_model, test_imgs)
# Out:
# torch.Size([5, 1, 28, 28])
# (5, 1, 28, 28)

# %% [markdown]
# Do we indeed see most values around $\mu=0$, $\sigma=1$ ? Is this in fact possible ? Why ? What compromise are we trying to achieve ?

# %% [markdown]
# __Your answer:__

# %% [markdown]
# Let us now compare the three models (AE diagonal covariance, AE full covariance and VAE) quantitavely.

# %% [markdown]
# # 4 Evaluating and comparing the models
#
# We will evaluate the models, in the following manner:
#
# - we train a simple convolutional neural network classifier on mnist, to a good accuracy
# - we generate images with each model
# - we find the average of the highest probability of the images according to the classifier, for each model. If this value is high, it means that on average the classifier considers that the images look like a number
#
# We will use the following convoluional architecture for the classifier:
#
# - conv2d, filter size  3Ã—3 , 32 filters, stride=(2,2), padding="SAME"
# - ReLU
# - conv2d, filter size  3Ã—3 , 32 filters, stride=(2,2), padding="SAME"
# - ReLU
# - MaxPool2D, stride=(2,2)
# - Flatten
# - Dense layer
#
# Now, define the model. To make things easier, use the ```torch.nn.Sequential``` API (there is no need for a Class in this simple case).

# %%
learning_rate = 0.01
n_epochs = 20
batch_size = 64
nb_classes = int(mnist_trainset.targets.max()+1)

# number of convolutional filters to use
nb_filters = 32
# convolution kernel size
kernel_size = (3, 3)
# size of pooling area for max pooling
pool_size = (2, 2)

# --- Size of the successive layers
n_h_0 = 1 #greyscale input images
n_h_1 = nb_filters
n_h_2 = nb_filters

mnist_classification_model = nn.Sequential(
    nn.Conv2d(n_h_0, n_h_1, kernel_size=kernel_size),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=pool_size),
    nn.Conv2d(n_h_1, n_h_2, kernel_size=kernel_size),
    nn.ReLU(),
    nn.Linear(n_h_2, nb_classes),
    nn.Softmax(dim=1)
)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mnist_classification_model.parameters(), lr=learning_rate)

# %% [markdown]
# Create a function to calculate accuracy, instead of loss

# %%
def get_accuracy(x_pred,x_label):
  acc = torch.sum(x_pred == x_label)/(x_pred.shape[0])
  return acc

# %% [markdown]
# Now, train the model. You should be able to achieve an accuracy close to 1.00 within 20 epochs

# %%
train_losses=[]
valid_losses=[]

for epoch in range(0,n_epochs):
  train_loss=0.0

  for batch_idx, (imgs, labels) in enumerate(mnist_train_loader):

    # set the gradients back to 0
    optimizer.zero_grad()
    predict=mnist_classification_model(imgs)
    # apply loss function
    loss=criterion(predict,labels)
    acc = get_accuracy(torch.argmax(predict,dim=1),labels)
    # backpropagation
    loss.backward()
    optimizer.step()
    train_loss=loss.item()
  print('Epoch:{} Train Loss:{:.4f} Accuracy:{:.4f}'.format(epoch,train_loss/imgs.shape[0],acc))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[65], line 11
#       7 for batch_idx, (imgs, labels) in enumerate(mnist_train_loader):
#       8
#       9   # set the gradients back to 0
#      10   optimizer.zero_grad()
# ---> 11   predict=mnist_classification_model(imgs)
#      12   # apply loss function
#      13   loss=criterion(predict,labels)
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/venv-dl/lib/python3.11/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (45056x11 and 32x10)

# %% [markdown]
# ### Evaluate the average maximum prediction of the images generated by each generative model (higher is better)
#
# Now, we will evaluate the models. For each ones, produce a certain number of images, and put those images through the classification network. Then find the maximum class probability of each image, and average it over all the images. We will use this as a metric to evaluate each model.
#
# __CAREFUL__: the output of the network does __not__ include the Softmax layer, so you will have to carry it out, with:
# - ```torch.nn.Softmax()(...)```
#
# Define this metric now:

# %%
def generative_model_score(imgs_in,classification_model):
  gen_score = ... # FILL IN CODE HERE
  return(gen_score)

# %% [markdown]
# Now, generate some images with each of the three models, and evaluate these models:

# %%
imgs_diagonal_gaussian = generate_images_diagonal_gaussian(ae_model,z_average,z_sigma,n_images = 50)
imgs_non_diagonal_gaussian = generate_images_non_diagonal_gaussian(ae_model,z_average,z_covariance,n_images = 50)
imgs_vae = generate_images_vae(vae_model,n_images=50)

# average of maximum of first model
diagonal_gaussian_score = float(generative_model_score(imgs_diagonal_gaussian,mnist_classification_model))
non_diagonal_gaussian_score = float(generative_model_score(imgs_non_diagonal_gaussian,mnist_classification_model))
vae_gaussian_score = float(generative_model_score(imgs_vae,mnist_classification_model))

print("Diagonal gaussian generative model score : ",diagonal_gaussian_score)
print("Non diagonal gaussian generative model score : ",non_diagonal_gaussian_score)
print("Variational autoencoder model score: ",vae_gaussian_score)

# %% [markdown]
# Please answer the following questions:
#
# - Which model is better quantitatively ?
# - Do the quantitative result support the qualitative results ?
# - Can you see any drawbacks of this method of evaluation ?
# - Can you propose any more sophisticated models than the multivariate Gaussian approach (apart from the variational autoencoder) ?

# %% [markdown]
# __Your answer__

# %% [markdown]
# ## 5 Conclusion
#
# Summarise the advantages and disadvantages of the variational autoencoder, with respect with what you have seen in this lab. In particular, discuss the following points :
# - The advantages/drawbacks of the Gaussian model in the latent space ($q_\theta(z|x)$)
# - The advantages/drawbacks of the Bernoulli or Gaussian models for the image space ($p_\theta(x|z)$)
# - To what extent is the initial goal achieved, ie creating an autoencoder whose latent codes follow a (multi-dimensional) normal distribution;

# %% [markdown]
# __Answer__
